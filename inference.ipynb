# %%
import numpy as np
from matplotlib import pyplot as plt
import pandas as pd
from hyperparams import get_train_test_split, create_param_grid, clfs
import seaborn as sns
import shap
import importlib

from sklearn.model_selection import ParameterSampler
from sklearn.base import BaseEstimator, TransformerMixin
from sklearn.feature_selection import SelectFromModel, SelectKBest, f_regression, r_regression, mutual_info_regression
from sklearn.decomposition import PCA, FactorAnalysis
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, VotingClassifier, StackingClassifier
from sklearn.model_selection import train_test_split, RandomizedSearchCV
from sklearn.preprocessing import OneHotEncoder, MinMaxScaler, PolynomialFeatures, SplineTransformer, KBinsDiscretizer, \
     StandardScaler, OrdinalEncoder, LabelEncoder
from sklearn.pipeline import Pipeline, make_pipeline
from sklearn.compose import ColumnTransformer
from sklearn.metrics import mean_absolute_error, r2_score, get_scorer_names, accuracy_score, f1_score, precision_score, \
     confusion_matrix, balanced_accuracy_score, ConfusionMatrixDisplay, classification_report
from sklearn.model_selection import RandomizedSearchCV, StratifiedKFold, KFold, train_test_split, cross_val_score, GridSearchCV, cross_validate
from sklearn.svm import SVC
from xgboost.sklearn import XGBClassifier
from lightgbm.sklearn import LGBMClassifier
import warnings 
warnings.filterwarnings("ignore")
# Number of random trials
NUM_TRIALS = 1

# Load the dataset
df = pd.read_csv('rapamycinTrain.tsv', sep='\t', low_memory=True)
df_ = pd.read_csv('allTrain.tsv', sep='\t', low_memory=True)
label = "Rapamycin_response"
# X_train, X_test, y_train, y_test, features, labels = get_train_test_split(df)

# %%
df_.type
# Out:
# 0       Breast
# 1       Breast
# 2       Breast
# 3       Breast
# 4       Breast
# 5     BrainCNS
# 6     BrainCNS
# 7     BrainCNS
# 8     BrainCNS
# 9     BrainCNS
# 10       Bowel
# 11       Bowel
# 12       Bowel
# 13       Bowel
# 14       Bowel
# 15        Lung
# 16        Lung
# 17        Lung
# 18        Lung
# 19        Lung
# 20        Lung
# 21        Lung
# 22       Blood
# 23       Blood
# 24       Blood
# 25       Blood
# 26        Skin
# 27        Skin
# 28        Skin
# 29        Skin
# 30        Skin
# 31        Skin
# 32       Ovary
# 33       Ovary
# 34       Ovary
# 35       Ovary
# 36       Ovary
# 37       Ovary
# 38    Prostate
# 39    Prostate
# 40      Kidney
# 41      Kidney
# 42      Kidney
# 43      Kidney
# 44      Kidney
# 45      Kidney
# 46      Kidney
# 47      Kidney
# Name: type, dtype: object

# %%
df.type
# Out:
# Breast_SQ68           Breast
# Breast_EI813          Breast
# Breast_PV9            Breast
# Breast_KY76           Breast
# Breast_EPQV2          Breast
# BrainCNS_BXX24      BrainCNS
# BrainCNS_JYV1       BrainCNS
# BrainCNS_NZ6        BrainCNS
# BrainCNS_MKT49      BrainCNS
# BrainCNS_QMQT2      BrainCNS
# Bowel_PCEM5            Bowel
# Bowel_WPJG932          Bowel
# Bowel_OY8              Bowel
# Bowel_ZMEK961          Bowel
# Bowel_KRW49            Bowel
# Lung_ND782              Lung
# Lung_KWV9               Lung
# Lung_WSJM17             Lung
# Lung_UJGS7              Lung
# Lung_XKM274             Lung
# Lung_ZK56               Lung
# Lung_MN34               Lung
# Blood_ZS5              Blood
# Blood_VQU9             Blood
# Blood_TKZ1             Blood
# Blood_FV5              Blood
# Skin_GMZV17             Skin
# Skin_ONW428             Skin
# Skin_IV21               Skin
# Skin_EJT91              Skin
# Skin_BZDY16             Skin
# Skin_FIXK19             Skin
# Ovary_PM7              Ovary
# Ovary_KK2              Ovary
# Ovary_HZ923            Ovary
# Ovary_WAV732           Ovary
# Ovary_MTWX729          Ovary
# Ovary_OLCT2            Ovary
# Prostate_CTZ7       Prostate
# Prostate_EZQR275    Prostate
# Kidney_NUX52          Kidney
# Kidney_RROA432        Kidney
# Kidney_SZ892          Kidney
# Kidney_DW4            Kidney
# Kidney_SUKK247        Kidney
# Kidney_SA2            Kidney
# Kidney_YUHC74         Kidney
# Kidney_JN167          Kidney
# Name: type, dtype: object

# %%
ful_res = pd.read_csv('outputs/cv_results_Fulvestrant_response.csv')

# %%
temp2 = ful_res.sort_values('accuracy', ascending=False).reset_index()

# %%
ful_res.isna().sum()
# Out:
# seed            0
# feat_sel        0
# models          0
# model_params    0
# accuracy        0
# f1              0
# dtype: int64

# %%
def group_results(cv_results):
    cv_results_all = cv_results.groupby(['seed','feat_sel','models'])[['accuracy', 'f1']].mean()
    cv_results_all[['accuracy_std', 'f1_std']] = cv_results.groupby(['seed','feat_sel','models'])[['accuracy', 'f1']].std()
    cv_results_all = cv_results_all.fillna(0)
    cv_results_all = cv_results_all.sort_values(['accuracy', 'accuracy_std'],ascending=False)

    cv_results_ = cv_results.groupby(['feat_sel','models'])[['accuracy', 'f1']].mean()#.sort_values(['accuracy', 'f1'],ascending=False)
    cv_results_[['accuracy_std', 'f1_std']] = ful_res.groupby(['feat_sel','models'])[['accuracy', 'f1']].std()#.sort_values(['accuracy', 'f1'],ascending=False)
    cv_results_ = cv_results_.fillna(0)
    cv_results_ = cv_results_.sort_values(['accuracy', 'accuracy_std'],ascending=False)
    return cv_results_all, cv_results_

# %%
def filter_results(cv_results, thresh=0.7):
    cv_results_all, _ = group_results(cv_results)
    filtered_res = cv_results_all[cv_results_all['accuracy'] >= thresh].sort_values('accuracy_std').reset_index()
    true_res = cv_results.sort_values('accuracy', ascending=False).reset_index()
    merged_df = pd.merge(true_res, filtered_res, on=['seed', 'feat_sel', 'models'], how='inner')[['feat_sel', 'models', 'model_params']]
    return merged_df

# %%
def calc_shap(pipe, X_train, y_train, X_test):
    pipe.fit(X_train, y_train)
    model = pipe.named_steps['clf']
    feat_bool = pipe.named_steps['feats'].get_support()
    selected_feats = X_train.iloc[:,feat_bool]
    print(f"------{ pipe['clf'].__class__.__name__ }-----")
    explainer = shap.KernelExplainer(model.predict, selected_feats)
    shap_values = explainer.shap_values(X_test.iloc[:,feat_bool])
    return shap_values, X_test.iloc[:,feat_bool]

# %%
def get_model(model_str):
    model_str = model_str.split("'")[1]
    model_ls = model_str.rsplit('.', 1)
    mod = ".".join(model_ls[:-1])
    module = importlib.import_module(mod)
    model_class = getattr(module, model_ls[-1])
    return model_class

def merge_dictionaries(dict1, dict2):
    from collections import Counter
    counter1 = Counter(dict1)
    counter2 = Counter(dict2)

    merged_counter = counter1 + counter2
    merged_dict = dict(merged_counter)

    return merged_dict

# %%
label = "Rapamycin_response"
def get_feature_imps(cv_results, X_train, y_train, X_test, label):
    import ast
    shap_importance = {}
    for fsm_str, model_str, mp_str in cv_results[["feat_sel", "models", "model_params"]].values:
        fsm = get_model(fsm_str)
        model = get_model(model_str)
        mp = ast.literal_eval(mp_str)
        p = Pipeline([("feats", SelectFromModel(fsm(), max_features=200)), ("clf", model(**mp))])
        sv, xt = calc_shap(p, X_train, y_train[label], X_test)
        svdf = pd.DataFrame(sv, columns=xt.columns.tolist())
        vals = np.abs(svdf.values).mean(0)
        temp_dict = dict(zip(xt.columns.tolist(), vals))
        shap_importance = merge_dictionaries(shap_importance, temp_dict)

    return shap_importance

# %%
ful_res_all, ful_res_ = group_results(ful_res)

# %%
temp = temp.reset_index()

# %%
temp2
# Out:
#      index  seed                                           feat_sel  \
# 0       38     1          <class 'lightgbm.sklearn.LGBMClassifier'>
# 1        4     0          <class 'lightgbm.sklearn.LGBMClassifier'>
# 2       94     0          <class 'lightgbm.sklearn.LGBMClassifier'>
# 3       64     0            <class 'xgboost.sklearn.XGBClassifier'>
# 4       73     2  <class 'sklearn.linear_model._logistic.Logisti...
# ..     ...   ...                                                ...
# 145     14     2          <class 'lightgbm.sklearn.LGBMClassifier'>
# 146    115     2  <class 'sklearn.ensemble._forest.RandomForestC...
# 147     92     0          <class 'lightgbm.sklearn.LGBMClassifier'>
# 148     81     1  <class 'sklearn.linear_model._logistic.Logisti...
# 149    111     1          <class 'lightgbm.sklearn.LGBMClassifier'>
#
#                                                 models  \
# 0    <class 'sklearn.ensemble._gb.GradientBoostingC...
# 1    <class 'sklearn.linear_model._logistic.Logisti...
# 2    <class 'sklearn.neighbors._classification.KNei...
# 3                   <class 'sklearn.svm._classes.SVC'>
# 4                   <class 'sklearn.svm._classes.SVC'>
# ..                                                 ...
# 145  <class 'sklearn.linear_model._logistic.Logisti...
# 146  <class 'sklearn.ensemble._weight_boosting.AdaB...
# 147  <class 'sklearn.neighbors._classification.KNei...
# 148          <class 'lightgbm.sklearn.LGBMClassifier'>
# 149  <class 'sklearn.ensemble._weight_boosting.AdaB...
#
#                                           model_params  accuracy        f1
# 0    {'ccp_alpha': 0.0, 'criterion': 'friedman_mse'...    1.0000  1.000000
# 1    {'C': 0.78, 'class_weight': 'balanced', 'dual'...    1.0000  1.000000
# 2    {'algorithm': 'ball_tree', 'leaf_size': 5, 'me...    1.0000  1.000000
# 3    {'C': 0.8477, 'break_ties': False, 'cache_size...    0.9375  0.903704
# 4    {'C': 0.3242, 'break_ties': False, 'cache_size...    0.9375  0.903704
# ..                                                 ...       ...       ...
# 145  {'C': 0.67, 'class_weight': 'balanced', 'dual'...    0.3750  0.711111
# 146  {'algorithm': 'SAMME.R', 'base_estimator': 'de...    0.3750  0.600000
# 147  {'algorithm': 'kd_tree', 'leaf_size': 4, 'metr...    0.3750  0.600000
# 148  {'boosting_type': 'gbdt', 'class_weight': 'bal...    0.3750  0.600000
# 149  {'algorithm': 'SAMME.R', 'base_estimator': 'de...    0.2500  0.457143
#
# [150 rows x 7 columns]

# %%
pd.merge(temp2, temp, on=['seed', 'feat_sel', 'models'], how='inner')
# Out:
#    index  seed                                           feat_sel  \
# 0     38     1          <class 'lightgbm.sklearn.LGBMClassifier'>
# 1     36     1          <class 'lightgbm.sklearn.LGBMClassifier'>
# 2      4     0          <class 'lightgbm.sklearn.LGBMClassifier'>
# 3      2     0          <class 'lightgbm.sklearn.LGBMClassifier'>
# 4     73     2  <class 'sklearn.linear_model._logistic.Logisti...
# 5      1     0  <class 'sklearn.ensemble._forest.RandomForestC...
# 6     76     0          <class 'lightgbm.sklearn.LGBMClassifier'>
# 7     41     2            <class 'xgboost.sklearn.XGBClassifier'>
# 8     35     1  <class 'sklearn.linear_model._logistic.Logisti...
#
#                                               models  \
# 0  <class 'sklearn.ensemble._gb.GradientBoostingC...
# 1  <class 'sklearn.ensemble._gb.GradientBoostingC...
# 2  <class 'sklearn.linear_model._logistic.Logisti...
# 3  <class 'sklearn.linear_model._logistic.Logisti...
# 4                 <class 'sklearn.svm._classes.SVC'>
# 5  <class 'sklearn.linear_model._logistic.Logisti...
# 6          <class 'lightgbm.sklearn.LGBMClassifier'>
# 7  <class 'sklearn.ensemble._gb.GradientBoostingC...
# 8  <class 'sklearn.ensemble._gb.GradientBoostingC...
#
#                                         model_params  accuracy_x      f1_x  \
# 0  {'ccp_alpha': 0.0, 'criterion': 'friedman_mse'...      1.0000  1.000000
# 1  {'ccp_alpha': 0.0, 'criterion': 'friedman_mse'...      0.5000  0.711111
# 2  {'C': 0.78, 'class_weight': 'balanced', 'dual'...      1.0000  1.000000
# 3  {'C': 0.45, 'class_weight': 'balanced', 'dual'...      0.5625  0.638095
# 4  {'C': 0.3242, 'break_ties': False, 'cache_size...      0.9375  0.903704
# 5  {'C': 0.23, 'class_weight': 'balanced', 'dual'...      0.9375  0.906667
# 6  {'boosting_type': 'gbdt', 'class_weight': 'bal...      0.8750  0.819048
# 7  {'ccp_alpha': 0.0, 'criterion': 'friedman_mse'...      0.7500  0.886275
# 8  {'ccp_alpha': 0.0, 'criterion': 'squared_error...      0.7500  0.633333
#
#    accuracy_y      f1_y  accuracy_std    f1_std
# 0     0.75000  0.855556      0.353553  0.204275
# 1     0.75000  0.855556      0.353553  0.204275
# 2     0.78125  0.819048      0.309359  0.255905
# 3     0.78125  0.819048      0.309359  0.255905
# 4     0.93750  0.903704      0.000000  0.000000
# 5     0.93750  0.906667      0.000000  0.000000
# 6     0.87500  0.819048      0.000000  0.000000
# 7     0.75000  0.886275      0.000000  0.000000
# 8     0.75000  0.633333      0.000000  0.000000

# %%
merged_df = pd.merge(temp2, temp, on=['seed', 'feat_sel', 'models'], how='inner')[['feat_sel', 'models', 'model_params', 'accuracy_x']]

# %%
merged_df
# Out:
#                                             feat_sel  \
# 0          <class 'lightgbm.sklearn.LGBMClassifier'>
# 1          <class 'lightgbm.sklearn.LGBMClassifier'>
# 2          <class 'lightgbm.sklearn.LGBMClassifier'>
# 3          <class 'lightgbm.sklearn.LGBMClassifier'>
# 4  <class 'sklearn.linear_model._logistic.Logisti...
# 5  <class 'sklearn.ensemble._forest.RandomForestC...
# 6          <class 'lightgbm.sklearn.LGBMClassifier'>
# 7            <class 'xgboost.sklearn.XGBClassifier'>
# 8  <class 'sklearn.linear_model._logistic.Logisti...
#
#                                               models  \
# 0  <class 'sklearn.ensemble._gb.GradientBoostingC...
# 1  <class 'sklearn.ensemble._gb.GradientBoostingC...
# 2  <class 'sklearn.linear_model._logistic.Logisti...
# 3  <class 'sklearn.linear_model._logistic.Logisti...
# 4                 <class 'sklearn.svm._classes.SVC'>
# 5  <class 'sklearn.linear_model._logistic.Logisti...
# 6          <class 'lightgbm.sklearn.LGBMClassifier'>
# 7  <class 'sklearn.ensemble._gb.GradientBoostingC...
# 8  <class 'sklearn.ensemble._gb.GradientBoostingC...
#
#                                         model_params  accuracy_x
# 0  {'ccp_alpha': 0.0, 'criterion': 'friedman_mse'...      1.0000
# 1  {'ccp_alpha': 0.0, 'criterion': 'friedman_mse'...      0.5000
# 2  {'C': 0.78, 'class_weight': 'balanced', 'dual'...      1.0000
# 3  {'C': 0.45, 'class_weight': 'balanced', 'dual'...      0.5625
# 4  {'C': 0.3242, 'break_ties': False, 'cache_size...      0.9375
# 5  {'C': 0.23, 'class_weight': 'balanced', 'dual'...      0.9375
# 6  {'boosting_type': 'gbdt', 'class_weight': 'bal...      0.8750
# 7  {'ccp_alpha': 0.0, 'criterion': 'friedman_mse'...      0.7500
# 8  {'ccp_alpha': 0.0, 'criterion': 'squared_error...      0.7500

# %%
ful_res_all.head(15)
# Out:
#                                                                                                             accuracy  \
# seed feat_sel                                           models
# 0    <class 'sklearn.ensemble._forest.RandomForestCl... <class 'sklearn.linear_model._logistic.Logistic...  0.937500
# 2    <class 'sklearn.linear_model._logistic.Logistic... <class 'sklearn.svm._classes.SVC'>                  0.937500
# 0    <class 'lightgbm.sklearn.LGBMClassifier'>          <class 'lightgbm.sklearn.LGBMClassifier'>           0.875000
#                                                         <class 'sklearn.linear_model._logistic.Logistic...  0.781250
# 1    <class 'lightgbm.sklearn.LGBMClassifier'>          <class 'sklearn.ensemble._gb.GradientBoostingCl...  0.750000
#      <class 'sklearn.linear_model._logistic.Logistic... <class 'sklearn.ensemble._gb.GradientBoostingCl...  0.750000
# 2    <class 'xgboost.sklearn.XGBClassifier'>            <class 'sklearn.ensemble._gb.GradientBoostingCl...  0.750000
# 0    <class 'xgboost.sklearn.XGBClassifier'>            <class 'sklearn.svm._classes.SVC'>                  0.687500
# 2    <class 'lightgbm.sklearn.LGBMClassifier'>          <class 'lightgbm.sklearn.LGBMClassifier'>           0.687500
# 0    <class 'sklearn.linear_model._logistic.Logistic... <class 'sklearn.ensemble._weight_boosting.AdaBo...  0.687500
# 2    <class 'sklearn.linear_model._logistic.Logistic... <class 'sklearn.ensemble._gb.GradientBoostingCl...  0.666667
# 0    <class 'lightgbm.sklearn.LGBMClassifier'>          <class 'sklearn.neighbors._classification.KNeig...  0.625000
# 2    <class 'lightgbm.sklearn.LGBMClassifier'>          <class 'sklearn.svm._classes.SVC'>                  0.625000
#      <class 'xgboost.sklearn.XGBClassifier'>            <class 'lightgbm.sklearn.LGBMClassifier'>           0.625000
# 0    <class 'sklearn.linear_model._logistic.Logistic... <class 'xgboost.sklearn.XGBClassifier'>             0.593750
#
#                                                                                                                   f1  \
# seed feat_sel                                           models
# 0    <class 'sklearn.ensemble._forest.RandomForestCl... <class 'sklearn.linear_model._logistic.Logistic...  0.906667
# 2    <class 'sklearn.linear_model._logistic.Logistic... <class 'sklearn.svm._classes.SVC'>                  0.903704
# 0    <class 'lightgbm.sklearn.LGBMClassifier'>          <class 'lightgbm.sklearn.LGBMClassifier'>           0.819048
#                                                         <class 'sklearn.linear_model._logistic.Logistic...  0.819048
# 1    <class 'lightgbm.sklearn.LGBMClassifier'>          <class 'sklearn.ensemble._gb.GradientBoostingCl...  0.855556
#      <class 'sklearn.linear_model._logistic.Logistic... <class 'sklearn.ensemble._gb.GradientBoostingCl...  0.633333
# 2    <class 'xgboost.sklearn.XGBClassifier'>            <class 'sklearn.ensemble._gb.GradientBoostingCl...  0.886275
# 0    <class 'xgboost.sklearn.XGBClassifier'>            <class 'sklearn.svm._classes.SVC'>                  0.781264
# 2    <class 'lightgbm.sklearn.LGBMClassifier'>          <class 'lightgbm.sklearn.LGBMClassifier'>           0.840741
# 0    <class 'sklearn.linear_model._logistic.Logistic... <class 'sklearn.ensemble._weight_boosting.AdaBo...  0.800000
# 2    <class 'sklearn.linear_model._logistic.Logistic... <class 'sklearn.ensemble._gb.GradientBoostingCl...  0.749524
# 0    <class 'lightgbm.sklearn.LGBMClassifier'>          <class 'sklearn.neighbors._classification.KNeig...  0.770370
# 2    <class 'lightgbm.sklearn.LGBMClassifier'>          <class 'sklearn.svm._classes.SVC'>                  0.720000
#      <class 'xgboost.sklearn.XGBClassifier'>            <class 'lightgbm.sklearn.LGBMClassifier'>           0.720000
# 0    <class 'sklearn.linear_model._logistic.Logistic... <class 'xgboost.sklearn.XGBClassifier'>             0.772549
#
#                                                                                                             accuracy_std  \
# seed feat_sel                                           models
# 0    <class 'sklearn.ensemble._forest.RandomForestCl... <class 'sklearn.linear_model._logistic.Logistic...      0.000000
# 2    <class 'sklearn.linear_model._logistic.Logistic... <class 'sklearn.svm._classes.SVC'>                      0.000000
# 0    <class 'lightgbm.sklearn.LGBMClassifier'>          <class 'lightgbm.sklearn.LGBMClassifier'>               0.000000
#                                                         <class 'sklearn.linear_model._logistic.Logistic...      0.309359
# 1    <class 'lightgbm.sklearn.LGBMClassifier'>          <class 'sklearn.ensemble._gb.GradientBoostingCl...      0.353553
#      <class 'sklearn.linear_model._logistic.Logistic... <class 'sklearn.ensemble._gb.GradientBoostingCl...      0.000000
# 2    <class 'xgboost.sklearn.XGBClassifier'>            <class 'sklearn.ensemble._gb.GradientBoostingCl...      0.000000
# 0    <class 'xgboost.sklearn.XGBClassifier'>            <class 'sklearn.svm._classes.SVC'>                      0.353553
# 2    <class 'lightgbm.sklearn.LGBMClassifier'>          <class 'lightgbm.sklearn.LGBMClassifier'>               0.353553
# 0    <class 'sklearn.linear_model._logistic.Logistic... <class 'sklearn.ensemble._weight_boosting.AdaBo...      0.000000
# 2    <class 'sklearn.linear_model._logistic.Logistic... <class 'sklearn.ensemble._gb.GradientBoostingCl...      0.190941
# 0    <class 'lightgbm.sklearn.LGBMClassifier'>          <class 'sklearn.neighbors._classification.KNeig...      0.330719
# 2    <class 'lightgbm.sklearn.LGBMClassifier'>          <class 'sklearn.svm._classes.SVC'>                      0.000000
#      <class 'xgboost.sklearn.XGBClassifier'>            <class 'lightgbm.sklearn.LGBMClassifier'>               0.000000
# 0    <class 'sklearn.linear_model._logistic.Logistic... <class 'xgboost.sklearn.XGBClassifier'>                 0.220971
#
#                                                                                                               f1_std
# seed feat_sel                                           models
# 0    <class 'sklearn.ensemble._forest.RandomForestCl... <class 'sklearn.linear_model._logistic.Logistic...  0.000000
# 2    <class 'sklearn.linear_model._logistic.Logistic... <class 'sklearn.svm._classes.SVC'>                  0.000000
# 0    <class 'lightgbm.sklearn.LGBMClassifier'>          <class 'lightgbm.sklearn.LGBMClassifier'>           0.000000
#                                                         <class 'sklearn.linear_model._logistic.Logistic...  0.255905
# 1    <class 'lightgbm.sklearn.LGBMClassifier'>          <class 'sklearn.ensemble._gb.GradientBoostingCl...  0.204275
#      <class 'sklearn.linear_model._logistic.Logistic... <class 'sklearn.ensemble._gb.GradientBoostingCl...  0.000000
# 2    <class 'xgboost.sklearn.XGBClassifier'>            <class 'sklearn.ensemble._gb.GradientBoostingCl...  0.000000
# 0    <class 'xgboost.sklearn.XGBClassifier'>            <class 'sklearn.svm._classes.SVC'>                  0.173156
# 2    <class 'lightgbm.sklearn.LGBMClassifier'>          <class 'lightgbm.sklearn.LGBMClassifier'>           0.089043
# 0    <class 'sklearn.linear_model._logistic.Logistic... <class 'sklearn.ensemble._weight_boosting.AdaBo...  0.000000
# 2    <class 'sklearn.linear_model._logistic.Logistic... <class 'sklearn.ensemble._gb.GradientBoostingCl...  0.059002
# 0    <class 'lightgbm.sklearn.LGBMClassifier'>          <class 'sklearn.neighbors._classification.KNeig...  0.206479
# 2    <class 'lightgbm.sklearn.LGBMClassifier'>          <class 'sklearn.svm._classes.SVC'>                  0.000000
#      <class 'xgboost.sklearn.XGBClassifier'>            <class 'lightgbm.sklearn.LGBMClassifier'>           0.000000
# 0    <class 'sklearn.linear_model._logistic.Logistic... <class 'xgboost.sklearn.XGBClassifier'>             0.160832

# %%
temp = ful_res_all[ful_res_all['accuracy'] >= 0.70].sort_values('accuracy_std')

# %%
get_feature_imps(merged_df, X_train, y_train, X_test, "Fulvestrant_response")
# Out:
# ------GradientBoostingClassifier-----
#   0%|          | 0/14 [00:00<?, ?it/s]
# ------GradientBoostingClassifier-----
#   0%|          | 0/14 [00:00<?, ?it/s]
# ------LogisticRegression-----
#   0%|          | 0/14 [00:00<?, ?it/s]
# ------LogisticRegression-----
#   0%|          | 0/14 [00:00<?, ?it/s]
# ------SVC-----
#   0%|          | 0/14 [00:00<?, ?it/s]
# ------LogisticRegression-----
#   0%|          | 0/14 [00:00<?, ?it/s]
# ------LGBMClassifier-----
#   0%|          | 0/14 [00:00<?, ?it/s]
# ------GradientBoostingClassifier-----
#   0%|          | 0/14 [00:00<?, ?it/s]
# ------GradientBoostingClassifier-----
#   0%|          | 0/14 [00:00<?, ?it/s]
# {'type': 0.49260193387196655,
#  'mut_C1orf222': 0.005656903224477074,
#  'mut_CAMTA1': 0.004732119344602808,
#  'mut_H6PD': 0.04694867589468317,
#  'mut_SPEN': 0.006583723484787072,
#  'mut_HSPG2': 0.007333240255374085,
#  'mut_ZSCAN20': 0.004846320735786162,
#  'mut_CSMD2': 0.0037335766841414047,
#  'mut_MACF1': 0.004476504759462121,
#  'mut_CDCP2': 0.010748626240413952,
#  'mut_LRRC7': 0.09875688251555945,
#  'mut_ADGRL2': 0.004886003100545071,
#  'mut_COL11A1': 0.0035973431070915928,
#  'mut_CHI3L2': 0.25258756477735417,
#  'mut_NOTCH2': 0.0028585718945741976,
#  'mut_PDE4DIP': 0.13597260620132695,
#  'mut_OTUD7B': 0.005299627534799436,
#  'mut_RHBG': 0.006410000345569172,
#  'mut_SPTA1': 0.10215868265314466,
#  'mut_ASPM': 0.03363770122121409,
#  'mut_CACNA1S': 0.04259023649780553,
#  'mut_USH2A': 0.005424817527335616,
#  'mut_APOB': 0.022378462042446465,
#  'mut_LTBP1': 0.0029994229634712102,
#  'mut_PRKD3': 0.004980057694181541,
#  'mut_PREPL': 0.005063819959349862,
#  'mut_SPTBN1': 0.005774856988152499,
#  'mut_USP34': 0.004558128445011933,
#  'mut_ALMS1': 0.0043443164029034805,
#  'mut_LCT': 0.03719909260661569,
#  'mut_LRP1B': 0.03740446330285031,
#  'mut_GALNT13': 0.003723317527299825,
#  'mut_TANC1': 0.005985160732065672,
#  'mut_SCN2A': 0.004365431959152104,
#  'mut_XIRP2': 0.004671938091045396,
#  'mut_LRP2': 0.26306408826022765,
#  'mut_SCRN3': 0.0044370280695034195,
#  'mut_TTN': 0.0051812563933056124,
#  'mut_DNAH7': 0.003951787300465445,
#  'mut_ERBB4': 0.005557911754365159,
#  'mut_ABCA12': 0.005271029796002625,
#  'mut_FN1': 0.004156133441903072,
#  'mut_COL4A4': 0.0029393263749161137,
#  'mut_COL6A3': 0.005755653204790608,
#  'mut_NUP210': 0.004580986940022537,
#  'mut_XIRP1': 0.008099621149297284,
#  'mut_SETD2': 0.006122513113750361,
#  'mut_COL7A1': 0.003891373843279551,
#  'mut_CELSR3': 0.004641303635725828,
#  'mut_MAGI1': 0.0038435771923901714,
#  'mut_OR5K3': 0.01050796344912112,
#  'mut_DZIP3': 0.004627302573148067,
#  'mut_RETNLB': 0.007541608783891009,
#  'mut_POLQ': 0.003047982210664557,
#  'mut_KALRN': 0.0034584412942319466,
#  'mut_CEP70': 0.005243852694052466,
#  'mut_WWTR1': 0.006145156663458709,
#  'mut_HTR3E': 0.004081428198255824,
#  'mut_KIAA1109': 0.0036107292622737574,
#  'mut_FAT4': 0.1011166761737732,
#  'mut_PCDH10': 0.005012973866350872,
#  'mut_DCHS2': 0.01170340925105236,
#  'mut_ADAMTS16': 0.004016985776670275,
#  'mut_CDH6': 0.004425678675530021,
#  'mut_PDZD2': 0.0038383009349273528,
#  'mut_LIFR': 0.0042052959360016455,
#  'mut_BDP1': 0.00486463902555772,
#  'mut_ZNF366': 0.006824526921693765,
#  'mut_DMGDH': 0.006329140145659502,
#  'mut_VCAN': 0.0035496828675759436,
#  'mut_APC': 0.0049289834826771965,
#  'mut_ZNF474': 0.0027891106407433933,
#  'mut_FBN2': 0.004699910389716656,
#  'mut_ADAMTS19': 0.0050441021286382216,
#  'mut_SPINK5': 0.0051938299198074555,
#  'mut_FAT2': 0.006189899805998703,
#  'mut_DOCK2': 0.005308961437988551,
#  'mut_OR2V2': 0.006001243070929748,
#  'mut_DNAH8': 0.0062122418293613394,
#  'mut_CUL9': 0.004740126957689632,
#  'mut_ZNF318': 0.009540107910415128,
#  'mut_PKHD1': 0.006429388912656287,
#  'mut_COL12A1': 0.003155340434829502,
#  'mut_MDN1': 0.005639422592465974,
#  'mut_HIVEP2': 0.006290808205878021,
#  'mut_SYNE1': 0.006402871615985963,
#  'mut_PKD1L1': 0.004109337432660515,
#  'mut_ZNF804B': 0.008463746830039883,
#  'mut_RELN': 0.006714190706239676,
#  'mut_LAMB4': 0.009613509627333733,
#  'mut_PPP1R3A': 0.004346685362610892,
#  'mut_ASB15': 0.003678632664524973,
#  'mut_PLXNA4': 0.004551811904417169,
#  'mut_BRAF': 0.003970255665060954,
#  'mut_CNTNAP2': 0.010882457389906581,
#  'mut_KMT2C': 0.005084204692444022,
#  'mut_TEX15': 0.0028473643643673937,
#  'mut_RP1': 0.004790323171991549,
#  'mut_PREX2': 0.0033776695946660714,
#  'mut_RIMS2': 0.0036105824236255754,
#  'mut_CSMD3': 0.019940328828902686,
#  'mut_FER1L6': 0.0029444776503886145,
#  'mut_FAM135B': 0.006518774282672092,
#  'mut_COL22A1': 0.004707323603052292,
#  'mut_PLEC': 0.005058361611816625,
#  'mut_CER1': 0.006647949496682396,
#  'mut_TEK': 0.004077121045068493,
#  'mut_TRPM6': 0.004320469086822322,
#  'mut_ROR2': 0.0030999438350522096,
#  'mut_ZNF462': 0.004075520092183692,
#  'mut_CCDC7': 0.0028026027902231733,
#  'mut_RBP3': 0.004526437576770033,
#  'mut_ANK3': 0.007195923600854921,
#  'mut_KAT6B': 0.005025466504604017,
#  'mut_SORCS3': 0.005572457991779037,
#  'mut_ATRNL1': 0.0028330050228709586,
#  'mut_TACC2': 0.004740437560675439,
#  'mut_OR52D1': 0.006658311020949574,
#  'mut_OR5L2': 0.004912589728547765,
#  'mut_TNKS1BP1': 0.004557144115343393,
#  'mut_AHNAK': 0.0025352773824572684,
#  'mut_GUCY1A2': 0.004276852870121488,
#  'mut_TECTA': 0.003891590547309424,
#  'mut_AKAP3': 0.005909666823925062,
#  'mut_LRRK2': 0.008047781483627912,
#  'mut_COL2A1': 0.0032792009840099815,
#  'mut_LRP1': 0.004978654612285853,
#  'mut_GLI1': 0.006727594447335526,
#  'mut_TRHDE': 0.0041822865546874205,
#  'mut_LRRIQ1': 0.023730544963552713,
#  'mut_GNPTAB': 0.006017372008321771,
#  'mut_CIT': 0.026273939291677203,
#  'mut_KDM2B': 0.003873750868780128,
#  'mut_SBNO1': 0.004956083061310351,
#  'mut_FLT3': 0.006077322363759951,
#  'mut_RXFP2': 0.004701964183440015,
#  'mut_FREM2': 0.003998679170783757,
#  'mut_ZC3H13': 0.003298072993681336,
#  'mut_KCNH5': 0.005378069326191466,
#  'mut_NRXN3': 0.004478674065423524,
#  'mut_UNC79': 0.0034683926330700728,
#  'mut_HERC2': 0.005721105777800915,
#  'mut_DMXL2': 0.004322874426977159,
#  'mut_MYO9A': 0.002849412144033667,
#  'mut_AKAP13': 0.005099065491655392,
#  'mut_DNAH3': 0.0055372040648998455,
#  'mut_KCTD19': 0.003598805793086702,
#  'mut_TP53': 0.0457390835775862,
#  'mut_DNAH2': 0.004279938134029751,
#  'mut_MYH2': 0.005629614017939652,
#  'mut_DNAH9': 0.0039006016925896784,
#  'mut_GPR179': 0.004113134781722014,
#  'mut_SPAG9': 0.003796576329655156,
#  'mut_CLTC': 0.004244119354241738,
#  'mut_ABCA8': 0.00746650245800904,
#  'mut_ABCA10': 0.005208139558909287,
#  'mut_LAMA1': 0.01970280054265869,
#  'mut_LAMA3': 0.0063932666847870785,
#  'mut_ALPK2': 0.003799501914893581,
#  'mut_RTTN': 0.003834490839270898,
#  'mut_TMPRSS9': 0.006422418773585284,
#  'mut_ZNF527': 0.004122533430803227,
#  'mut_RYR1': 0.004030126357397025,
#  'mut_ARID1A': 0.004865474750162825,
#  'mut_OVGP1': 0.006537330152745962,
#  'mut_BRINP3': 0.00411124327869537,
#  'mut_CRB1': 0.004620234409186201,
#  'mut_ITPKB': 0.004718343265637392,
#  'mut_EPAS1': 0.0032833180086977863,
#  'mut_IL1R2': 0.003522768077459821,
#  'mut_MAP2': 0.01956842760173495,
#  'mut_COL4A3': 0.0035783110139324392,
#  'mut_SLIT2': 0.0035725315205084145,
#  'mut_CWH43': 0.003111292522819624,
#  'mut_ANK2': 0.0041961360090871525,
#  'mut_DNAH5': 0.005037902845753085,
#  'mut_CDH10': 0.004527713292115176,
#  'mut_NIPBL': 0.002522265975349019,
#  'mut_PTPRK': 0.0029246715045929124,
#  'mut_MICALL2': 0.004050255195274936,
#  'mut_PTPRZ1': 0.004086539368582686,
#  'mut_TG': 0.0036279491786378164,
#  'mut_PCDH15': 0.0024437133091801144,
#  'mut_OR52N1': 0.0757672854590892,
#  'mut_NRXN2': 0.006155599952310031,
#  'mut_C2CD3': 0.0038755346887954156,
#  'mut_SORL1': 0.0037535190537635,
#  'mut_KRAS': 0.0044525748345132345,
#  'mut_KIF21A': 0.0034938101347294103,
#  'mut_SACS': 0.00408114589278007,
#  'mut_PCDH9': 0.004629599632723167,
#  'mut_FANCM': 0.003718618231135041,
#  'mut_SYNE2': 0.0024642468149428313,
#  'mut_SLC8A3': 0.002909372603442442,
#  'mut_ALPK3': 0.005618851703296981,
#  'mut_MYH1': 0.004142349097921811,
#  'mut_BZRAP1': 0.0033654863416063686,
#  'mut_CTNND2': 0.004075222009071524,
#  'mut_C12orf60': 0.05612903049250814,
#  'mut_FLT1': 0.0056422584661836835,
#  'rna_ISG15': 0.003916278833265769,
#  'rna_PIK3CD-AS2': 0.0031497943430343666,
#  'rna_FBXO6': 0.018469429106366522,
#  'rna_FBXO2': 0.003447353445941495,
#  'rna_MFAP2': 0.004240640370215501,
#  'rna_SFN': 0.004076679144054305,
#  'rna_THEMIS2': 0.006593848616848294,
#  'rna_CITED4': 0.004294092307013137,
#  'rna_SLC2A1': 0.004617588607187919,
#  'rna_PDE4B': 0.0054794531381720125,
#  'rna_F3': 0.004464840535162215,
#  'rna_SORT1': 0.0041109587427852305,
#  'rna_TXNIP': 0.004303118636276738,
#  'rna_LOC645166': 0.0037126413391335086,
#  'rna_ECM1': 0.019615157050872842,
#  'rna_S100A11': 0.0031298988466194238,
#  'rna_S100A6': 0.005266511276631363,
#  'rna_S100A16': 0.19412799208771514,
#  'rna_IFI16': 0.003988498897468645,
#  'rna_TSTD1': 0.003986052578501893,
#  'rna_ATP1B1': 0.0037632313241615445,
#  'rna_MIR1231': 0.0058778353938975505,
#  'rna_SNORA77': 0.0027711049864928513,
#  'rna_ID2': 0.0036444861605476712,
#  'rna_C2orf74': 0.00510282479818744,
#  'rna_LOC654342': 0.0037795976569430616,
#  'rna_MAL': 0.003804416460453987,
#  'rna_FHL2': 0.003793334641028484,
#  'rna_PAX8-AS1': 0.003853306967034179,
#  'rna_LINC01116': 0.0044700151415263505,
#  'rna_COL5A2': 0.0034056215647608173,
#  'rna_NRP2': 0.003615502637367686,
#  'rna_ARL4C': 0.0036342019445066223,
#  'rna_RAMP1': 0.003521067735304201,
#  'rna_HES6': 0.004588751464279646,
#  'rna_CAMK1': 0.005588798170714708,
#  'rna_FN1': 0.0036255445385278435,
#  'rna_CDCP1': 0.004495991183357579,
#  'rna_FILIP1L': 0.02175924266676048,
#  'rna_CSTA': 0.006927894241417628,
#  'rna_MYLK': 0.004227914245910761,
#  'rna_MGLL': 0.019971148823063035,
#  'rna_RBP1': 0.0037159232327512413,
#  'rna_TM4SF1': 0.004169109679548802,
#  'rna_SPON2': 0.003180215507982521,
#  'rna_LIMCH1': 0.004221099393091125,
#  'rna_UCHL1': 0.004630651368655632,
#  'rna_EREG': 0.004142873770603218,
#  'rna_SPP1': 0.003574592525789697,
#  'rna_LEF1': 0.003998903456109956,
#  'rna_SNORA47': 0.003466320479949535,
#  'rna_ANKRD34B': 0.002691988666970826,
#  'rna_FAM151B': 0.003979875415823085,
#  'rna_LOC100505841': 0.003972556265288323,
#  'rna_PDLIM4': 0.0039675559770824985,
#  'rna_PITX1': 0.00395126269480266,
#  'rna_TGFBI': 0.00461642149198664,
#  'rna_EIF4EBP3': 0.003363357458612256,
#  'rna_SPARC': 0.0040532173871876175,
#  'rna_TRIM7': 0.008666838556055845,
#  'rna_HIST1H3C': 0.004165429517529582,
#  'rna_HIST1H2BG': 0.003110960094648527,
#  'rna_HIST1H1D': 0.004633625788153593,
#  'rna_HIST1H3F': 0.0031087667245071945,
#  'rna_HIST1H2BH': 0.005421328110974388,
#  'rna_HIST1H3G': 0.007479515336422634,
#  'rna_HIST1H4I': 0.0042494699333855065,
#  'rna_HIST1H1B': 0.0037070210733820006,
#  'rna_PSMB8': 0.0036441529289037876,
#  'rna_FAM46A': 0.0037749248937778337,
#  'rna_CITED2': 0.004656170275280719,
#  'rna_RPS18P9': 0.0045492445825246475,
#  'rna_SOD2': 0.003459207268085764,
#  'rna_AGR2': 0.0036992827072948277,
#  'rna_HOXA9': 0.004772160499865024,
#  'rna_IGFBP3': 0.0033738616897442345,
#  'rna_TFPI2': 0.003497252780199013,
#  'rna_ASNS': 0.00624374720672337,
#  'rna_PEG10': 0.004820900951730416,
#  'rna_VGF': 0.0050054641369678046,
#  'rna_MTRNR2L6': 0.002941365154936325,
#  'rna_LRRC61': 0.00319966276453708,
#  'rna_DEFA1': 0.003414694032373498,
#  'rna_DEFA1B': 0.004848033595663773,
#  'rna_DEFA3': 0.0029207151954840985,
#  'rna_DLC1': 0.0033133930362039396,
#  'rna_CLU': 0.020382795129227443,
#  'rna_SCARA3': 0.0038008711814199905,
#  'rna_ZNF703': 0.0030116979480621945,
#  'rna_PLAT': 0.0029472047228616457,
#  'rna_CEBPD': 0.007317481191215371,
#  'rna_SNAI2': 0.0036645125640941446,
#  'rna_PDP1': 0.004491470691693942,
#  'rna_LAPTM4B': 0.004413624524317488,
#  'rna_TRIB1': 0.004867689674509108,
#  'rna_NDRG1': 0.0037890640573190267,
#  'rna_LY6E': 0.0038485507091282596,
#  'rna_CDKN2A': 0.0033542582186587193,
#  'rna_MTAP': 0.006372705225511658,
#  'rna_TPM2': 0.00584782686808723,
#  'rna_CTSL': 0.004027563382920492,
#  'rna_MIR2278': 0.004092220754094562,
#  'rna_COL15A1': 0.0040165442584261185,
#  'rna_TNC': 0.0030386164939155092,
#  'rna_IER5L': 0.002828792641991619,
#  'rna_PRRX2': 0.016307348316301918,
#  'rna_AKR1C3': 0.0035703594476660014,
#  'rna_VIM': 0.004021790847387193,
#  'rna_CUTC': 0.003739358129823813,
#  'rna_SNORA12': 0.004202073842155456,
#  'rna_SCD': 0.0036052330478748744,
#  'rna_GSTO2': 0.0031494775481042967,
#  'rna_HBE1': 0.003845435718860665,
#  'rna_OR51B5': 0.002901226516983279,
#  'rna_CAND1.11': 0.003392546325105119,
#  'rna_SVIP': 0.0036335369765029485,
#  'rna_MDK': 0.003302866358712726,
#  'rna_PRG2': 0.004539722012905877,
#  'rna_GAL': 0.003935400283525216,
#  'rna_FGF19': 0.0038038071868364927,
#  'rna_PRSS23': 0.004196247530919392,
#  'rna_SNORA25': 0.003769284541475808,
#  'rna_SNORA1': 0.004081648021317068,
#  'rna_LAYN': 0.003757415993462291,
#  'rna_ETS1': 0.004682792390325596,
#  'rna_FKBP11': 0.0037360118473397427,
#  'rna_KRT8': 0.004428438970979697,
#  'rna_KRT18': 0.005066301563759914,
#  'rna_HOXC9': 0.004174462683978322,
#  'rna_GTSF1': 0.0036648149808390894,
#  'rna_DUSP6': 0.004410485048079333,
#  'rna_C12orf75': 0.002934805930744494,
#  'rna_LINC00173': 0.004097339384432484,
#  'rna_OASL': 0.003614627739128293,
#  'rna_RNASE2': 0.004331076590620981,
#  'rna_PRMT5-AS1': 0.013324808997224024,
#  'rna_BMP4': 0.0044097748008058175,
#  'rna_SIX1': 0.00390459754728728,
#  'rna_IFI27': 0.003914722422824912,
#  'rna_SNURF': 0.005023104626489644,
#  'rna_C15orf52': 0.003268929316224612,
#  'rna_THBS1': 0.003940817144481697,
#  'rna_ANXA2': 0.0039584544601076795,
#  'rna_TPM1': 0.0036114067600407362,
#  'rna_ANPEP': 0.004029612715773002,
#  'rna_IL32': 0.006333002204499647,
#  'rna_MT1E': 0.007025488703052805,
#  'rna_ADGRG1': 0.004068892440809723,
#  'rna_SNORA46': 0.004090391955065725,
#  'rna_CDH3': 0.00414011568183329,
#  'rna_CYBA': 0.003486049571466653,
#  'rna_SNORA48': 0.004100149984823656,
#  'rna_CENPV': 0.004259158908218958,
#  'rna_MTRNR2L1': 0.0038247225920558215,
#  'rna_CCL5': 0.005253124285598446,
#  'rna_MPO': 0.003420242511377177,
#  'rna_MIR142': 0.0031511858839967663,
#  'rna_ICAM2': 0.003681257670192506,
#  'rna_MIR5047': 0.004059062938064574,
#  'rna_LGALS3BP': 0.03445835026827293,
#  'rna_PTPRM': 0.004811007644752601,
#  'rna_RAB31': 0.003813831074625796,
#  'rna_PALM': 0.004346228633962528,
#  'rna_AZU1': 0.006552500704960966,
#  'rna_PRTN3': 0.003104954215134609,
#  'rna_LPPR3': 0.00482249456218103,
#  'rna_ELANE': 0.004828277998819949,
#  'rna_CFD': 0.05333813433783264,
#  'rna_GDF15': 0.0022797691473379405,
#  'rna_ISYNA1': 0.004038471683905295,
#  'rna_CEBPA': 0.003908982842163215,
#  'rna_TYROBP': 0.003582024525442407,
#  'rna_C19orf33': 0.004125875157941771,
#  'rna_APOC2': 0.005179559129788595,
#  'rna_RPL13AP5': 0.005849620035963832,
#  'rna_IL4I1': 0.0044119997850899685,
#  'rna_SIRPB1': 0.0038395060842002556,
#  'rna_SNORD17': 0.002856975389688222,
#  'rna_RIN2': 0.0035010742427585007,
#  'rna_TGM2': 0.0029338864456513007,
#  'rna_MTRNR2L3': 0.00629370104662271,
#  'rna_CDH4': 0.0037705440798151886,
#  'rna_MIR133A2': 0.003931421727298261,
#  'rna_NTSR1': 0.0032728508588909877,
#  'rna_KCNQ2': 0.005736504531743182,
#  'rna_BACE2': 0.0038773638481539984,
#  'rna_MIR3198-1': 0.004618888519037119,
#  'rna_PRAME': 0.005025059612352752,
#  'rna_MIF-AS1': 0.003476270057491071,
#  'rna_MIF': 0.003737451931353765,
#  'rna_SELM': 0.0032161390978011203,
#  'rna_SYNGR1': 0.004750989217478152,
#  'rna_KLHDC7B': 0.0035086041665256516,
#  'rna_MAGEB2': 0.003311490774511941,
#  'rna_MTRNR2L10': 0.0036144339323324055,
#  'rna_NGFRAP1': 0.0035700428161327393,
#  'rna_SOWAHD': 0.003132830572646266,
#  'rna_MOSPD1': 0.0030721146699431486,
#  'rna_RNA5-8S5': 0.003653271481444139,
#  'rna_DFFB': 0.0005214149877931122,
#  'rna_SPSB1': 0.0019014967772378263,
#  'rna_MIIP': 0.0011619124057544842,
#  'rna_IFI6': 0.0008148942393695508,
#  'rna_PHACTR4': 0.0012928204983666811,
#  'rna_EPB41': 0.0003505456596931024,
#  'rna_COL16A1': 0.0005368484774321521,
#  'rna_PARS2': 0.00020630008416358666,
#  'rna_RAVER2': 0.0007029177536424689,
#  'rna_ALG14': 0.0008343555564099416,
#  'rna_STXBP3': 0.0012283457325010883,
#  'rna_RBM15': 0.00023210087083719644,
#  'rna_RSBN1': 0.0020525986415835043,
#  'rna_OTUD7B': 0.0018277887126171076,
#  'rna_S100A2': 0.0008939797015754353,
#  'rna_TOR3A': 0.0006775187127318182,
#  'rna_ZNF281': 0.0011618346884655058,
#  'rna_LAMB3': 0.0011601218154733976,
#  'rna_GNPAT': 0.0010335946683467047,
#  'rna_PCNXL2': 0.001028600080985363,
#  'rna_PREB': 0.00027136052406927924,
#  'rna_CLIP4': 0.00045188196358881817,
#  'rna_HEATR5B': 0.0014539236183856406,
#  'rna_LOC339803': 0.0016431800424110757,
#  'rna_GMCL1': 0.0010470033867040166,
#  'rna_SNRPG': 0.00016233115444217006,
#  'rna_DUSP2': 0.00042468733729147023,
#  'rna_SSFA2': 0.0007441235940275836,
#  'rna_ADAM23': 0.0006079201614951164,
#  'rna_SP140L': 0.0010179637795738705,
#  'rna_PRRT3': 0.0006101193365723141,
#  'rna_C3orf18': 0.0018376117308969062,
#  'rna_HP09053': 0.0009875451846567064,
#  'rna_RNF7': 0.0009166680126369512,
#  'rna_CLDN1': 0.004528863158842774,
#  'rna_TMEM129': 0.0007945877552732185,
#  'rna_CHIC2': 0.00048737504253340916,
#  'rna_LOC105377348': 0.001005027150855939,
#  'rna_SLC10A7': 0.0010917189400435495,
#  'rna_MND1': 0.001587219545570225,
#  'rna_FBXO8': 0.001051486252480665,
#  'rna_UGT3A2': 0.00039004894431278735,
#  'rna_IQGAP2': 0.0015893780943610973,
#  'rna_LINC01023': 0.0010041686213048803,
#  'rna_JADE2': 0.0007175312215567646,
#  'rna_PCDH1': 0.000664275374226554,
#  'rna_PLAC8L1': 0.001131990822643197,
#  'rna_NQO2': 0.0013700478144058493,
#  'rna_JARID2-AS1': 0.0008625167622796005,
#  'rna_HIST1H2AD': 0.00028501989791656035,
#  'rna_TRIM27': 0.0008120594426812126,
#  'rna_HLA-B': 0.001717570818754794,
#  'rna_TAF11': 0.0008792452159426462,
#  'rna_FKBP5': 0.0012856706296269517,
#  'rna_MAPK13': 0.0005739276006239245,
#  'rna_ENPP5': 0.0009049979496937866,
#  'rna_GSTA4': 0.00035305427547352414,
#  'rna_SESN1': 0.0007218454839663712,
#  'rna_LINC00957': 0.0010024765433708398,
#  'rna_ZNF107': 0.000936907465682993,
#  'rna_SRI': 0.0010455174760700583,
#  'rna_PPP1R35': 0.000736541123102945,
#  'rna_LOC101927746': 0.00012214056167721515,
#  'rna_KMT2E': 0.00035775687415732897,
#  'rna_ST7': 0.0003651190578707516,
#  'rna_ZNF783': 0.0012098886768429648,
#  'rna_DNAJB6': 0.001363880509203539,
#  'rna_PDGFRL': 0.001580630368705502,
#  'rna_RNF5P1': 0.0006740731048216938,
#  'rna_SMIM19': 0.0007146562195661426,
#  'rna_RAB2A': 0.0008621850657281176,
#  'rna_ZBTB10': 0.0006561497744041725,
#  'rna_STK3': 0.0007238085810936923,
#  'rna_FAM201A': 0.001338422662498191,
#  'rna_MRPL41': 0.0009316267934526572,
#  'rna_RPP38': 0.0003854268844748464,
#  'rna_MLLT10': 0.0006194336304141862,
#  'rna_FZD8': 0.001175602589033657,
#  'rna_MTRNR2L7': 0.0012999167607636287,
#  'rna_DKK1': 0.009741685445470187,
#  'rna_GRID1': 0.0005712415407325573,
#  'rna_ACSL5': 0.0009945942424668965,
#  'rna_CACUL1': 0.0004320484611646897,
#  'rna_IFITM3': 0.0006228185586732472,
#  'rna_RPLP2': 0.0015491925386130396,
#  'rna_UQCC3': 0.0015053977178940592,
#  'rna_RPS3': 0.0008143270013551293,
#  'rna_WNT5B': 0.001214296921241419,
#  'rna_DIP2B': 0.0010721042848458374,
#  'rna_WIBG': 0.0007393972717898136,
#  'rna_MSRB3': 0.0003289436934227895,
#  'rna_SCYL2': 0.0014901555836294852,
#  'rna_CABP1': 0.000761323077682663,
#  'rna_SLC25A30': 0.0010145824556604844,
#  'rna_DIS3': 0.001093792180311769,
#  'rna_SLAIN1': 0.0014431452324045722,
#  'rna_MIR17HG': 0.0010483203867284172,
#  'rna_METTL17': 0.0006789332351020597,
#  'rna_SDR39U1': 0.0011833617607156777,
#  'rna_IGBP1P1': 0.0005906142887152181,
#  'rna_ACOT1': 0.0010958209399944312,
#  'rna_NRDE2': 0.0011557831935401874,
#  'rna_C14orf159': 0.0009803050834249634,
#  'rna_GPR132': 0.0017259990942312135,
#  'rna_TMEM62': 0.0008379645044449147,
#  'rna_SNX33': 0.0011929039692921697,
#  'rna_LOC642423': 0.0008650508051953114,
#  'rna_DET1': 0.00014578929000376594,
#  'rna_ROGDI': 0.0011940842989757953,
#  'rna_ALG1': 0.0007011050114148893,
#  'rna_KIAA0556': 0.001041830993998129,
#  'rna_LCAT': 0.0014683984468128726,
#  'rna_SPATA2L': 0.0008959864210325168,
#  'rna_DEF8': 0.0017057423595848492,
#  'rna_TNFSF13': 0.0006812903499437315,
#  'rna_MPDU1': 0.0010767742336051562,
#  'rna_FLII': 0.000897649355790992,
#  'rna_SPAG5-AS1': 0.0009924801423310768,
#  'rna_MYO18A': 0.0010637680587993498,
#  'rna_TAOK1': 0.0015698602379734267,
#  'rna_NR1D1': 0.0008736919992147241,
#  'rna_KRT33B': 0.0008590244748201585,
#  'rna_MRPS23': 0.0007195180312735214,
#  'rna_NME1': 0.0018647132978896416,
#  'rna_SEC14L1': 0.000747302656543898,
#  'rna_NOTUM': 0.0005793955033255,
#  'rna_ENOSF1': 0.0010750527481761937,
#  'rna_LDLRAD4': 0.0006988772854749506,
#  'rna_DSC2': 0.00033706960396151286,
#  'rna_RBFA': 0.0014452046950728901,
#  'rna_ATP5D': 0.0017566467227067477,
#  'rna_SLC25A23': 0.0005251672666493381,
#  'rna_ZNF562': 0.0006325742979895598,
#  'rna_RTBDN': 0.001959903752862609,
#  'rna_DKKL1': 0.0006600878762622528,
#  'rna_MYH14': 0.0011149908130163662,
#  'rna_CACNG6': 0.001207836829004549,
#  'rna_TSEN34': 0.00046734756887906675,
#  'rna_PDRG1': 0.0010629662853186483,
#  'rna_MAFB': 0.0006162952858424093,
#  'rna_AURKA': 0.0006130740000303773,
#  'rna_PPP4R1L': 0.0005295035666410972,
#  'rna_HAR1A': 0.0008613729108039812,
#  'rna_BCR': 0.0007143651307555431,
#  'rna_H1F0': 0.0007989616345082983,
#  'rna_BIK': 0.00034132776580585964,
#  'rna_PDHA1': 0.0008364647328799126,
#  'rna_ARHGEF9': 0.00038724029504957804,
#  'rna_RNF113A': 0.0013439786767151577,
#  'rna_ZBTB33': 0.0013505783305212706,
#  'rna_LOC105373383': 0.00045016450513577215,
#  'rna_RPL10': 0.000918780802441746,
#  'rna_AGTRAP': 0.015627084167000295,
#  'rna_KTI12': 0.009357076163798803,
#  'rna_LGI3': 0.009407096171802016,
#  'rna_BBOX1-AS1': 0.039637521675337475,
#  'rna_ECI1': 0.01573796185140724}

# %%
ful_res_.head(15)
# Out:
#                                                                                                        accuracy  \
# feat_sel                                           models
# <class 'lightgbm.sklearn.LGBMClassifier'>          <class 'lightgbm.sklearn.LGBMClassifier'>           0.687500
# <class 'sklearn.linear_model._logistic.Logistic... <class 'sklearn.svm._classes.SVC'>                  0.645833
# <class 'sklearn.ensemble._forest.RandomForestCl... <class 'sklearn.linear_model._logistic.Logistic...  0.640625
# <class 'sklearn.linear_model._logistic.Logistic... <class 'sklearn.ensemble._gb.GradientBoostingCl...  0.614583
# <class 'lightgbm.sklearn.LGBMClassifier'>          <class 'sklearn.ensemble._gb.GradientBoostingCl...  0.593750
# <class 'xgboost.sklearn.XGBClassifier'>            <class 'sklearn.svm._classes.SVC'>                  0.562500
# <class 'sklearn.linear_model._logistic.Logistic... <class 'sklearn.ensemble._weight_boosting.AdaBo...  0.562500
# <class 'lightgbm.sklearn.LGBMClassifier'>          <class 'sklearn.neighbors._classification.KNeig...  0.553571
# <class 'sklearn.ensemble._forest.RandomForestCl... <class 'lightgbm.sklearn.LGBMClassifier'>           0.546875
# <class 'sklearn.linear_model._logistic.Logistic... <class 'xgboost.sklearn.XGBClassifier'>             0.546875
# <class 'lightgbm.sklearn.LGBMClassifier'>          <class 'sklearn.linear_model._logistic.Logistic...  0.531250
# <class 'xgboost.sklearn.XGBClassifier'>            <class 'sklearn.ensemble._gb.GradientBoostingCl...  0.512500
# <class 'lightgbm.sklearn.LGBMClassifier'>          <class 'sklearn.svm._classes.SVC'>                  0.512500
#                                                    <class 'sklearn.ensemble._bagging.BaggingClassi...  0.500000
#                                                    <class 'sklearn.ensemble._forest.RandomForestCl...  0.500000
#
#                                                                                                              f1  \
# feat_sel                                           models
# <class 'lightgbm.sklearn.LGBMClassifier'>          <class 'lightgbm.sklearn.LGBMClassifier'>           0.802910
# <class 'sklearn.linear_model._logistic.Logistic... <class 'sklearn.svm._classes.SVC'>                  0.817139
# <class 'sklearn.ensemble._forest.RandomForestCl... <class 'sklearn.linear_model._logistic.Logistic...  0.800523
# <class 'sklearn.linear_model._logistic.Logistic... <class 'sklearn.ensemble._gb.GradientBoostingCl...  0.708640
# <class 'lightgbm.sklearn.LGBMClassifier'>          <class 'sklearn.ensemble._gb.GradientBoostingCl...  0.816667
# <class 'xgboost.sklearn.XGBClassifier'>            <class 'sklearn.svm._classes.SVC'>                  0.749782
# <class 'sklearn.linear_model._logistic.Logistic... <class 'sklearn.ensemble._weight_boosting.AdaBo...  0.782571
# <class 'lightgbm.sklearn.LGBMClassifier'>          <class 'sklearn.neighbors._classification.KNeig...  0.772362
# <class 'sklearn.ensemble._forest.RandomForestCl... <class 'lightgbm.sklearn.LGBMClassifier'>           0.773203
# <class 'sklearn.linear_model._logistic.Logistic... <class 'xgboost.sklearn.XGBClassifier'>             0.773203
# <class 'lightgbm.sklearn.LGBMClassifier'>          <class 'sklearn.linear_model._logistic.Logistic...  0.730968
# <class 'xgboost.sklearn.XGBClassifier'>            <class 'sklearn.ensemble._gb.GradientBoostingCl...  0.762353
# <class 'lightgbm.sklearn.LGBMClassifier'>          <class 'sklearn.svm._classes.SVC'>                  0.702431
#                                                    <class 'sklearn.ensemble._bagging.BaggingClassi...  0.752941
#                                                    <class 'sklearn.ensemble._forest.RandomForestCl...  0.773856
#
#                                                                                                        accuracy_std  \
# feat_sel                                           models
# <class 'lightgbm.sklearn.LGBMClassifier'>          <class 'lightgbm.sklearn.LGBMClassifier'>               0.255155
# <class 'sklearn.linear_model._logistic.Logistic... <class 'sklearn.svm._classes.SVC'>                      0.252591
# <class 'sklearn.ensemble._forest.RandomForestCl... <class 'sklearn.linear_model._logistic.Logistic...      0.224624
# <class 'sklearn.linear_model._logistic.Logistic... <class 'sklearn.ensemble._gb.GradientBoostingCl...      0.169635
# <class 'lightgbm.sklearn.LGBMClassifier'>          <class 'sklearn.ensemble._gb.GradientBoostingCl...      0.272431
# <class 'xgboost.sklearn.XGBClassifier'>            <class 'sklearn.svm._classes.SVC'>                      0.250000
# <class 'sklearn.linear_model._logistic.Logistic... <class 'sklearn.ensemble._weight_boosting.AdaBo...      0.108253
# <class 'lightgbm.sklearn.LGBMClassifier'>          <class 'sklearn.neighbors._classification.KNeig...      0.202293
# <class 'sklearn.ensemble._forest.RandomForestCl... <class 'lightgbm.sklearn.LGBMClassifier'>               0.138585
# <class 'sklearn.linear_model._logistic.Logistic... <class 'xgboost.sklearn.XGBClassifier'>                 0.138585
# <class 'lightgbm.sklearn.LGBMClassifier'>          <class 'sklearn.linear_model._logistic.Logistic...      0.239629
# <class 'xgboost.sklearn.XGBClassifier'>            <class 'sklearn.ensemble._gb.GradientBoostingCl...      0.135497
# <class 'lightgbm.sklearn.LGBMClassifier'>          <class 'sklearn.svm._classes.SVC'>                      0.068465
#                                                    <class 'sklearn.ensemble._bagging.BaggingClassi...      0.000000
#                                                    <class 'sklearn.ensemble._forest.RandomForestCl...      0.000000
#
#                                                                                                          f1_std
# feat_sel                                           models
# <class 'lightgbm.sklearn.LGBMClassifier'>          <class 'lightgbm.sklearn.LGBMClassifier'>           0.080578
# <class 'sklearn.linear_model._logistic.Logistic... <class 'sklearn.svm._classes.SVC'>                  0.097760
# <class 'sklearn.ensemble._forest.RandomForestCl... <class 'sklearn.linear_model._logistic.Logistic...  0.104319
# <class 'sklearn.linear_model._logistic.Logistic... <class 'sklearn.ensemble._gb.GradientBoostingCl...  0.063460
# <class 'lightgbm.sklearn.LGBMClassifier'>          <class 'sklearn.ensemble._gb.GradientBoostingCl...  0.126198
# <class 'xgboost.sklearn.XGBClassifier'>            <class 'sklearn.svm._classes.SVC'>                  0.116937
# <class 'sklearn.linear_model._logistic.Logistic... <class 'sklearn.ensemble._weight_boosting.AdaBo...  0.064535
# <class 'lightgbm.sklearn.LGBMClassifier'>          <class 'sklearn.neighbors._classification.KNeig...  0.129767
# <class 'sklearn.ensemble._forest.RandomForestCl... <class 'lightgbm.sklearn.LGBMClassifier'>           0.106054
# <class 'sklearn.linear_model._logistic.Logistic... <class 'xgboost.sklearn.XGBClassifier'>             0.106054
# <class 'lightgbm.sklearn.LGBMClassifier'>          <class 'sklearn.linear_model._logistic.Logistic...  0.145565
# <class 'xgboost.sklearn.XGBClassifier'>            <class 'sklearn.ensemble._gb.GradientBoostingCl...  0.085406
# <class 'lightgbm.sklearn.LGBMClassifier'>          <class 'sklearn.svm._classes.SVC'>                  0.024680
#                                                    <class 'sklearn.ensemble._bagging.BaggingClassi...  0.064803
#                                                    <class 'sklearn.ensemble._forest.RandomForestCl...  0.072452

# %% [markdown]
# probable best models `svc`, `Logistic`, `LGBM`, `GBC`

# %% [markdown]
# seems like `xgb` is not a good feature selector here

# %%
gef_res = pd.read_csv('outputs/cv_results_Gefitinib_response.csv')

# %%
gef_res.isna().sum()
# Out:
# seed            0
# feat_sel        0
# models          0
# model_params    0
# accuracy        0
# f1              0
# dtype: int64

# %%
gef_res_all, gef_res_ = group_results(gef_res)

# %%
gef_res_all
# Out:
#                                                                                                             accuracy  \
# seed feat_sel                                           models
# 0    <class 'sklearn.ensemble._forest.RandomForestCl... <class 'sklearn.ensemble._gb.GradientBoostingCl...  0.833333
# 1    <class 'lightgbm.sklearn.LGBMClassifier'>          <class 'sklearn.ensemble._weight_boosting.AdaBo...  0.833333
# 2    <class 'lightgbm.sklearn.LGBMClassifier'>          <class 'sklearn.ensemble._bagging.BaggingClassi...  0.761905
#      <class 'sklearn.linear_model._logistic.Logistic... <class 'xgboost.sklearn.XGBClassifier'>             0.750000
# 0    <class 'xgboost.sklearn.XGBClassifier'>            <class 'sklearn.linear_model._logistic.Logistic...  0.750000
# ...                                                                                                              ...
# 2    <class 'lightgbm.sklearn.LGBMClassifier'>          <class 'sklearn.svm._classes.SVC'>                  0.354167
#      <class 'sklearn.linear_model._logistic.Logistic... <class 'lightgbm.sklearn.LGBMClassifier'>           0.333333
# 1    <class 'xgboost.sklearn.XGBClassifier'>            <class 'sklearn.svm._classes.SVC'>                  0.285714
# 2    <class 'sklearn.ensemble._forest.RandomForestCl... <class 'xgboost.sklearn.XGBClassifier'>             0.250000
#                                                         <class 'sklearn.ensemble._gb.GradientBoostingCl...  0.166667
#
#                                                                                                                   f1  \
# seed feat_sel                                           models
# 0    <class 'sklearn.ensemble._forest.RandomForestCl... <class 'sklearn.ensemble._gb.GradientBoostingCl...  0.882051
# 1    <class 'lightgbm.sklearn.LGBMClassifier'>          <class 'sklearn.ensemble._weight_boosting.AdaBo...  0.882051
# 2    <class 'lightgbm.sklearn.LGBMClassifier'>          <class 'sklearn.ensemble._bagging.BaggingClassi...  0.800000
#      <class 'sklearn.linear_model._logistic.Logistic... <class 'xgboost.sklearn.XGBClassifier'>             0.827917
# 0    <class 'xgboost.sklearn.XGBClassifier'>            <class 'sklearn.linear_model._logistic.Logistic...  0.666667
# ...                                                                                                              ...
# 2    <class 'lightgbm.sklearn.LGBMClassifier'>          <class 'sklearn.svm._classes.SVC'>                  0.402165
#      <class 'sklearn.linear_model._logistic.Logistic... <class 'lightgbm.sklearn.LGBMClassifier'>           0.350000
# 1    <class 'xgboost.sklearn.XGBClassifier'>            <class 'sklearn.svm._classes.SVC'>                  0.400000
# 2    <class 'sklearn.ensemble._forest.RandomForestCl... <class 'xgboost.sklearn.XGBClassifier'>             0.333333
#                                                         <class 'sklearn.ensemble._gb.GradientBoostingCl...  0.242424
#
#                                                                                                             accuracy_std  \
# seed feat_sel                                           models
# 0    <class 'sklearn.ensemble._forest.RandomForestCl... <class 'sklearn.ensemble._gb.GradientBoostingCl...      0.000000
# 1    <class 'lightgbm.sklearn.LGBMClassifier'>          <class 'sklearn.ensemble._weight_boosting.AdaBo...      0.000000
# 2    <class 'lightgbm.sklearn.LGBMClassifier'>          <class 'sklearn.ensemble._bagging.BaggingClassi...      0.000000
#      <class 'sklearn.linear_model._logistic.Logistic... <class 'xgboost.sklearn.XGBClassifier'>                 0.117851
# 0    <class 'xgboost.sklearn.XGBClassifier'>            <class 'sklearn.linear_model._logistic.Logistic...      0.000000
# ...                                                                                                                  ...
# 2    <class 'lightgbm.sklearn.LGBMClassifier'>          <class 'sklearn.svm._classes.SVC'>                      0.265165
#      <class 'sklearn.linear_model._logistic.Logistic... <class 'lightgbm.sklearn.LGBMClassifier'>               0.000000
# 1    <class 'xgboost.sklearn.XGBClassifier'>            <class 'sklearn.svm._classes.SVC'>                      0.000000
# 2    <class 'sklearn.ensemble._forest.RandomForestCl... <class 'xgboost.sklearn.XGBClassifier'>                 0.000000
#                                                         <class 'sklearn.ensemble._gb.GradientBoostingCl...      0.000000
#
#                                                                                                               f1_std
# seed feat_sel                                           models
# 0    <class 'sklearn.ensemble._forest.RandomForestCl... <class 'sklearn.ensemble._gb.GradientBoostingCl...  0.000000
# 1    <class 'lightgbm.sklearn.LGBMClassifier'>          <class 'sklearn.ensemble._weight_boosting.AdaBo...  0.000000
# 2    <class 'lightgbm.sklearn.LGBMClassifier'>          <class 'sklearn.ensemble._bagging.BaggingClassi...  0.000000
#      <class 'sklearn.linear_model._logistic.Logistic... <class 'xgboost.sklearn.XGBClassifier'>             0.092513
# 0    <class 'xgboost.sklearn.XGBClassifier'>            <class 'sklearn.linear_model._logistic.Logistic...  0.000000
# ...                                                                                                              ...
# 2    <class 'lightgbm.sklearn.LGBMClassifier'>          <class 'sklearn.svm._classes.SVC'>                  0.225907
#      <class 'sklearn.linear_model._logistic.Logistic... <class 'lightgbm.sklearn.LGBMClassifier'>           0.000000
# 1    <class 'xgboost.sklearn.XGBClassifier'>            <class 'sklearn.svm._classes.SVC'>                  0.000000
# 2    <class 'sklearn.ensemble._forest.RandomForestCl... <class 'xgboost.sklearn.XGBClassifier'>             0.000000
#                                                         <class 'sklearn.ensemble._gb.GradientBoostingCl...  0.000000
#
# [91 rows x 4 columns]

# %%
gef_res_all[gef_res_all['accuracy'] >= 0.75].sort_values('accuracy_std')
# Out:
#                                                                                                             accuracy  \
# seed feat_sel                                           models
# 0    <class 'sklearn.ensemble._forest.RandomForestCl... <class 'sklearn.ensemble._gb.GradientBoostingCl...  0.833333
# 1    <class 'lightgbm.sklearn.LGBMClassifier'>          <class 'sklearn.ensemble._weight_boosting.AdaBo...  0.833333
# 2    <class 'lightgbm.sklearn.LGBMClassifier'>          <class 'sklearn.ensemble._bagging.BaggingClassi...  0.761905
# 0    <class 'xgboost.sklearn.XGBClassifier'>            <class 'sklearn.linear_model._logistic.Logistic...  0.750000
# 2    <class 'sklearn.linear_model._logistic.Logistic... <class 'xgboost.sklearn.XGBClassifier'>             0.750000
#
#                                                                                                                   f1  \
# seed feat_sel                                           models
# 0    <class 'sklearn.ensemble._forest.RandomForestCl... <class 'sklearn.ensemble._gb.GradientBoostingCl...  0.882051
# 1    <class 'lightgbm.sklearn.LGBMClassifier'>          <class 'sklearn.ensemble._weight_boosting.AdaBo...  0.882051
# 2    <class 'lightgbm.sklearn.LGBMClassifier'>          <class 'sklearn.ensemble._bagging.BaggingClassi...  0.800000
# 0    <class 'xgboost.sklearn.XGBClassifier'>            <class 'sklearn.linear_model._logistic.Logistic...  0.666667
# 2    <class 'sklearn.linear_model._logistic.Logistic... <class 'xgboost.sklearn.XGBClassifier'>             0.827917
#
#                                                                                                             accuracy_std  \
# seed feat_sel                                           models
# 0    <class 'sklearn.ensemble._forest.RandomForestCl... <class 'sklearn.ensemble._gb.GradientBoostingCl...      0.000000
# 1    <class 'lightgbm.sklearn.LGBMClassifier'>          <class 'sklearn.ensemble._weight_boosting.AdaBo...      0.000000
# 2    <class 'lightgbm.sklearn.LGBMClassifier'>          <class 'sklearn.ensemble._bagging.BaggingClassi...      0.000000
# 0    <class 'xgboost.sklearn.XGBClassifier'>            <class 'sklearn.linear_model._logistic.Logistic...      0.000000
# 2    <class 'sklearn.linear_model._logistic.Logistic... <class 'xgboost.sklearn.XGBClassifier'>                 0.117851
#
#                                                                                                               f1_std
# seed feat_sel                                           models
# 0    <class 'sklearn.ensemble._forest.RandomForestCl... <class 'sklearn.ensemble._gb.GradientBoostingCl...  0.000000
# 1    <class 'lightgbm.sklearn.LGBMClassifier'>          <class 'sklearn.ensemble._weight_boosting.AdaBo...  0.000000
# 2    <class 'lightgbm.sklearn.LGBMClassifier'>          <class 'sklearn.ensemble._bagging.BaggingClassi...  0.000000
# 0    <class 'xgboost.sklearn.XGBClassifier'>            <class 'sklearn.linear_model._logistic.Logistic...  0.000000
# 2    <class 'sklearn.linear_model._logistic.Logistic... <class 'xgboost.sklearn.XGBClassifier'>             0.092513

# %%
weights = merged_df['accuracy_x']/merged_df['accuracy_x'].iloc[0]
weights
# Out:
# 0    1.0000
# 1    0.5000
# 2    1.0000
# 3    0.5625
# 4    0.9375
# 5    0.9375
# 6    0.8750
# 7    0.7500
# 8    0.7500
# Name: accuracy_x, dtype: float64

# %%
import pandas as pd

# Example DataFrame
data = {
    'A': [1, 3, 5],
    'B': [4, 2, 6],
    'C': [7, 1, 8]
}

df = pd.DataFrame(data)

# Find the column name with the highest value for each row
max_column = df.idxmax(axis=1)

# Add a new column to the DataFrame with the column name having the highest value
df['max_column'] = max_column

# Display the result
print(df)
# Out:
#    A  B  C max_column
# 0  1  4  7          C
# 1  3  2  1          A
# 2  5  6  8          C

# %%
{k:[v] for k,v in max_column.to_dict().items()}
# Out:
# {0: ['C'], 1: ['A'], 2: ['C']}

# %%
from collections import Counter

data = {
    'A': [1, 3, 3, 5],
    'B': [4, 2, 6, 6],
    'C': [7, 1, 1, 8]
}



def find_max_freq_element(data):
    result = {}
    for key, values in data.items():
        # Use Counter to count the frequency of each element in the list
        counter = Counter(values)
        
        # Find the element with the highest frequency
        most_common_element, frequency = counter.most_common(1)[0]
        
        # Store the result in the dictionary
        result[key] = most_common_element
    return result

print(result)
# Out:
# {'A': 3, 'B': 6, 'C': 1}

# %%
pd.concat([pd.DataFrame(), df], axis=1)
# Out:
#    A  B  C max_column
# 0  1  4  7          C
# 1  3  2  1          A
# 2  5  6  8          C

# %%
df
# Out:
#    A  B  C max_column
# 0  1  4  7          C
# 1  3  2  1          A
# 2  5  6  8          C

# %%
gef_res_.reset_index()
# Out:
#                                              feat_sel  \
# 0   <class 'sklearn.linear_model._logistic.Logisti...
# 1           <class 'lightgbm.sklearn.LGBMClassifier'>
# 2           <class 'lightgbm.sklearn.LGBMClassifier'>
# 3           <class 'lightgbm.sklearn.LGBMClassifier'>
# 4             <class 'xgboost.sklearn.XGBClassifier'>
# 5   <class 'sklearn.ensemble._forest.RandomForestC...
# 6   <class 'sklearn.linear_model._logistic.Logisti...
# 7             <class 'xgboost.sklearn.XGBClassifier'>
# 8   <class 'sklearn.ensemble._forest.RandomForestC...
# 9           <class 'lightgbm.sklearn.LGBMClassifier'>
# 10          <class 'lightgbm.sklearn.LGBMClassifier'>
# 11            <class 'xgboost.sklearn.XGBClassifier'>
# 12  <class 'sklearn.linear_model._logistic.Logisti...
# 13  <class 'sklearn.ensemble._forest.RandomForestC...
# 14            <class 'xgboost.sklearn.XGBClassifier'>
# 15            <class 'xgboost.sklearn.XGBClassifier'>
# 16            <class 'xgboost.sklearn.XGBClassifier'>
# 17          <class 'lightgbm.sklearn.LGBMClassifier'>
# 18          <class 'lightgbm.sklearn.LGBMClassifier'>
# 19  <class 'sklearn.ensemble._forest.RandomForestC...
# 20  <class 'sklearn.ensemble._forest.RandomForestC...
# 21            <class 'xgboost.sklearn.XGBClassifier'>
# 22  <class 'sklearn.ensemble._forest.RandomForestC...
# 23  <class 'sklearn.linear_model._logistic.Logisti...
# 24  <class 'sklearn.linear_model._logistic.Logisti...
# 25  <class 'sklearn.ensemble._forest.RandomForestC...
# 26  <class 'sklearn.ensemble._forest.RandomForestC...
# 27  <class 'sklearn.linear_model._logistic.Logisti...
# 28          <class 'lightgbm.sklearn.LGBMClassifier'>
# 29  <class 'sklearn.linear_model._logistic.Logisti...
# 30  <class 'sklearn.linear_model._logistic.Logisti...
# 31  <class 'sklearn.ensemble._forest.RandomForestC...
# 32  <class 'sklearn.linear_model._logistic.Logisti...
# 33          <class 'lightgbm.sklearn.LGBMClassifier'>
# 34            <class 'xgboost.sklearn.XGBClassifier'>
# 35  <class 'sklearn.ensemble._forest.RandomForestC...
# 36  <class 'sklearn.linear_model._logistic.Logisti...
# 37            <class 'xgboost.sklearn.XGBClassifier'>
# 38          <class 'lightgbm.sklearn.LGBMClassifier'>
# 39            <class 'xgboost.sklearn.XGBClassifier'>
#
#                                                models  accuracy        f1  \
# 0             <class 'xgboost.sklearn.XGBClassifier'>  0.666667  0.701944
# 1   <class 'sklearn.linear_model._logistic.Logisti...  0.654762  0.663278
# 2   <class 'sklearn.ensemble._weight_boosting.AdaB...  0.630952  0.703526
# 3   <class 'sklearn.neighbors._classification.KNei...  0.619048  0.616667
# 4   <class 'sklearn.neighbors._classification.KNei...  0.610714  0.651910
# 5   <class 'sklearn.ensemble._gb.GradientBoostingC...  0.595238  0.615643
# 6   <class 'sklearn.ensemble._gb.GradientBoostingC...  0.592262  0.610806
# 7   <class 'sklearn.ensemble._gb.GradientBoostingC...  0.587302  0.651068
# 8   <class 'sklearn.neighbors._classification.KNei...  0.583333  0.618271
# 9   <class 'sklearn.ensemble._forest.RandomForestC...  0.583333  0.647917
# 10  <class 'sklearn.ensemble._bagging.BaggingClass...  0.571429  0.648889
# 11  <class 'sklearn.ensemble._bagging.BaggingClass...  0.555556  0.573810
# 12  <class 'sklearn.linear_model._logistic.Logisti...  0.543651  0.556902
# 13  <class 'sklearn.ensemble._bagging.BaggingClass...  0.537946  0.577172
# 14          <class 'lightgbm.sklearn.LGBMClassifier'>  0.537202  0.609306
# 15  <class 'sklearn.linear_model._logistic.Logisti...  0.517857  0.537637
# 16            <class 'xgboost.sklearn.XGBClassifier'>  0.517857  0.572698
# 17          <class 'lightgbm.sklearn.LGBMClassifier'>  0.517857  0.588889
# 18  <class 'sklearn.ensemble._gb.GradientBoostingC...  0.516369  0.583665
# 19            <class 'xgboost.sklearn.XGBClassifier'>  0.503401  0.574275
# 20  <class 'sklearn.ensemble._weight_boosting.AdaB...  0.502381  0.552337
# 21  <class 'sklearn.ensemble._forest.RandomForestC...  0.500000  0.554902
# 22  <class 'sklearn.ensemble._forest.ExtraTreesCla...  0.500000  0.540919
# 23  <class 'sklearn.ensemble._bagging.BaggingClass...  0.500000  0.450000
# 24  <class 'sklearn.ensemble._forest.RandomForestC...  0.500000  0.446320
# 25          <class 'lightgbm.sklearn.LGBMClassifier'>  0.494048  0.547004
# 26  <class 'sklearn.ensemble._forest.RandomForestC...  0.486111  0.396994
# 27  <class 'sklearn.neighbors._classification.KNei...  0.481151  0.531394
# 28  <class 'sklearn.ensemble._forest.ExtraTreesCla...  0.476190  0.544935
# 29          <class 'lightgbm.sklearn.LGBMClassifier'>  0.472222  0.482051
# 30                 <class 'sklearn.svm._classes.SVC'>  0.465774  0.518010
# 31                 <class 'sklearn.svm._classes.SVC'>  0.464286  0.530201
# 32  <class 'sklearn.ensemble._forest.ExtraTreesCla...  0.461310  0.503472
# 33            <class 'xgboost.sklearn.XGBClassifier'>  0.458333  0.454437
# 34  <class 'sklearn.ensemble._forest.ExtraTreesCla...  0.448810  0.509156
# 35  <class 'sklearn.linear_model._logistic.Logisti...  0.434524  0.500641
# 36  <class 'sklearn.ensemble._weight_boosting.AdaB...  0.414286  0.474725
# 37  <class 'sklearn.ensemble._weight_boosting.AdaB...  0.408730  0.480675
# 38                 <class 'sklearn.svm._classes.SVC'>  0.395833  0.434416
# 39                 <class 'sklearn.svm._classes.SVC'>  0.351190  0.438095
#
#     accuracy_std    f1_std
# 0       0.138585  0.106054
# 1       0.239629  0.145565
# 2       0.091998  0.119280
# 3       0.202293  0.129767
# 4       0.036084  0.051281
# 5       0.000000  0.000000
# 6       0.169635  0.063460
# 7       0.135497  0.085406
# 8       0.088388  0.078567
# 9       0.000000  0.072452
# 10      0.000000  0.064803
# 11      0.036084  0.083878
# 12      0.036084  0.038490
# 13      0.000000  0.072452
# 14      0.130104  0.090686
# 15      0.088388  0.000000
# 16      0.000000  0.072452
# 17      0.255155  0.080578
# 18      0.272431  0.126198
# 19      0.072169  0.118373
# 20      0.062500  0.096681
# 21      0.036084  0.038490
# 22      0.000000  0.000000
# 23      0.000000  0.088735
# 24      0.000000  0.068734
# 25      0.138585  0.106054
# 26      0.000000  0.000000
# 27      0.000000  0.000000
# 28      0.036084  0.077536
# 29      0.059839  0.101482
# 30      0.252591  0.097760
# 31      0.036084  0.062786
# 32      0.023623  0.069029
# 33      0.034233  0.078407
# 34      0.000000  0.000000
# 35      0.224624  0.104319
# 36      0.108253  0.064535
# 37      0.044194  0.041595
# 38      0.068465  0.024680
# 39      0.250000  0.116937

# %%
mit_res = pd.read_csv('outputs/cv_results_Mitomycin_response.csv')

# %%
mit_res.isna().sum()
# Out:
# seed            0
# feat_sel        0
# models          0
# model_params    0
# accuracy        0
# f1              0
# dtype: int64

# %%
mit_res_all, mit_res_ = group_results(mit_res)

# %%
mit_res_all
# Out:
#                                                                                                             accuracy  \
# seed feat_sel                                           models
# 0    <class 'lightgbm.sklearn.LGBMClassifier'>          <class 'lightgbm.sklearn.LGBMClassifier'>              0.875
#                                                         <class 'sklearn.ensemble._weight_boosting.AdaBo...     0.800
#      <class 'sklearn.linear_model._logistic.Logistic... <class 'sklearn.linear_model._logistic.Logistic...     0.800
#      <class 'xgboost.sklearn.XGBClassifier'>            <class 'lightgbm.sklearn.LGBMClassifier'>              0.800
#                                                         <class 'sklearn.svm._classes.SVC'>                     0.800
# ...                                                                                                              ...
#      <class 'sklearn.ensemble._forest.RandomForestCl... <class 'lightgbm.sklearn.LGBMClassifier'>              0.375
# 1    <class 'lightgbm.sklearn.LGBMClassifier'>          <class 'sklearn.ensemble._weight_boosting.AdaBo...     0.325
# 2    <class 'lightgbm.sklearn.LGBMClassifier'>          <class 'sklearn.ensemble._weight_boosting.AdaBo...     0.325
#      <class 'sklearn.linear_model._logistic.Logistic... <class 'sklearn.ensemble._forest.RandomForestCl...     0.300
#                                                         <class 'sklearn.neighbors._classification.KNeig...     0.225
#
#                                                                                                                   f1  \
# seed feat_sel                                           models
# 0    <class 'lightgbm.sklearn.LGBMClassifier'>          <class 'lightgbm.sklearn.LGBMClassifier'>           0.886003
#                                                         <class 'sklearn.ensemble._weight_boosting.AdaBo...  0.791667
#      <class 'sklearn.linear_model._logistic.Logistic... <class 'sklearn.linear_model._logistic.Logistic...  0.791667
#      <class 'xgboost.sklearn.XGBClassifier'>            <class 'lightgbm.sklearn.LGBMClassifier'>           0.800000
#                                                         <class 'sklearn.svm._classes.SVC'>                  0.800000
# ...                                                                                                              ...
#      <class 'sklearn.ensemble._forest.RandomForestCl... <class 'lightgbm.sklearn.LGBMClassifier'>           0.400000
# 1    <class 'lightgbm.sklearn.LGBMClassifier'>          <class 'sklearn.ensemble._weight_boosting.AdaBo...  0.333333
# 2    <class 'lightgbm.sklearn.LGBMClassifier'>          <class 'sklearn.ensemble._weight_boosting.AdaBo...  0.333333
#      <class 'sklearn.linear_model._logistic.Logistic... <class 'sklearn.ensemble._forest.RandomForestCl...  0.277778
#                                                         <class 'sklearn.neighbors._classification.KNeig...  0.222222
#
#                                                                                                             accuracy_std  \
# seed feat_sel                                           models
# 0    <class 'lightgbm.sklearn.LGBMClassifier'>          <class 'lightgbm.sklearn.LGBMClassifier'>                    0.0
#                                                         <class 'sklearn.ensemble._weight_boosting.AdaBo...           0.0
#      <class 'sklearn.linear_model._logistic.Logistic... <class 'sklearn.linear_model._logistic.Logistic...           0.0
#      <class 'xgboost.sklearn.XGBClassifier'>            <class 'lightgbm.sklearn.LGBMClassifier'>                    0.0
#                                                         <class 'sklearn.svm._classes.SVC'>                           0.0
# ...                                                                                                                  ...
#      <class 'sklearn.ensemble._forest.RandomForestCl... <class 'lightgbm.sklearn.LGBMClassifier'>                    0.0
# 1    <class 'lightgbm.sklearn.LGBMClassifier'>          <class 'sklearn.ensemble._weight_boosting.AdaBo...           0.0
# 2    <class 'lightgbm.sklearn.LGBMClassifier'>          <class 'sklearn.ensemble._weight_boosting.AdaBo...           0.0
#      <class 'sklearn.linear_model._logistic.Logistic... <class 'sklearn.ensemble._forest.RandomForestCl...           0.0
#                                                         <class 'sklearn.neighbors._classification.KNeig...           0.0
#
#                                                                                                             f1_std
# seed feat_sel                                           models
# 0    <class 'lightgbm.sklearn.LGBMClassifier'>          <class 'lightgbm.sklearn.LGBMClassifier'>              0.0
#                                                         <class 'sklearn.ensemble._weight_boosting.AdaBo...     0.0
#      <class 'sklearn.linear_model._logistic.Logistic... <class 'sklearn.linear_model._logistic.Logistic...     0.0
#      <class 'xgboost.sklearn.XGBClassifier'>            <class 'lightgbm.sklearn.LGBMClassifier'>              0.0
#                                                         <class 'sklearn.svm._classes.SVC'>                     0.0
# ...                                                                                                            ...
#      <class 'sklearn.ensemble._forest.RandomForestCl... <class 'lightgbm.sklearn.LGBMClassifier'>              0.0
# 1    <class 'lightgbm.sklearn.LGBMClassifier'>          <class 'sklearn.ensemble._weight_boosting.AdaBo...     0.0
# 2    <class 'lightgbm.sklearn.LGBMClassifier'>          <class 'sklearn.ensemble._weight_boosting.AdaBo...     0.0
#      <class 'sklearn.linear_model._logistic.Logistic... <class 'sklearn.ensemble._forest.RandomForestCl...     0.0
#                                                         <class 'sklearn.neighbors._classification.KNeig...     0.0
#
# [96 rows x 4 columns]

# %%
mit_res_all[mit_res_all['accuracy'] >= 0.70].sort_values('accuracy_std')
# Out:
#                                                                                                             accuracy  \
# seed feat_sel                                           models
# 0    <class 'lightgbm.sklearn.LGBMClassifier'>          <class 'lightgbm.sklearn.LGBMClassifier'>           0.875000
# 2    <class 'sklearn.ensemble._forest.RandomForestCl... <class 'xgboost.sklearn.XGBClassifier'>             0.708333
# 1    <class 'sklearn.linear_model._logistic.Logistic... <class 'sklearn.ensemble._gb.GradientBoostingCl...  0.708333
#      <class 'sklearn.ensemble._forest.RandomForestCl... <class 'sklearn.ensemble._gb.GradientBoostingCl...  0.750000
# 2    <class 'lightgbm.sklearn.LGBMClassifier'>          <class 'sklearn.ensemble._bagging.BaggingClassi...  0.775000
# 1    <class 'lightgbm.sklearn.LGBMClassifier'>          <class 'sklearn.ensemble._forest.ExtraTreesClas...  0.791667
# 0    <class 'sklearn.linear_model._logistic.Logistic... <class 'sklearn.ensemble._gb.GradientBoostingCl...  0.750000
#      <class 'xgboost.sklearn.XGBClassifier'>            <class 'sklearn.svm._classes.SVC'>                  0.800000
#                                                         <class 'lightgbm.sklearn.LGBMClassifier'>           0.800000
#      <class 'sklearn.linear_model._logistic.Logistic... <class 'sklearn.linear_model._logistic.Logistic...  0.800000
#      <class 'lightgbm.sklearn.LGBMClassifier'>          <class 'sklearn.ensemble._weight_boosting.AdaBo...  0.800000
# 2    <class 'xgboost.sklearn.XGBClassifier'>            <class 'xgboost.sklearn.XGBClassifier'>             0.800000
# 1    <class 'sklearn.ensemble._forest.RandomForestCl... <class 'sklearn.ensemble._forest.RandomForestCl...  0.700000
#                                                         <class 'xgboost.sklearn.XGBClassifier'>             0.725000
# 2    <class 'lightgbm.sklearn.LGBMClassifier'>          <class 'sklearn.ensemble._forest.RandomForestCl...  0.700000
# 1    <class 'lightgbm.sklearn.LGBMClassifier'>          <class 'xgboost.sklearn.XGBClassifier'>             0.708333
# 2    <class 'lightgbm.sklearn.LGBMClassifier'>          <class 'sklearn.ensemble._gb.GradientBoostingCl...  0.700000
# 1    <class 'sklearn.ensemble._forest.RandomForestCl... <class 'sklearn.linear_model._logistic.Logistic...  0.755556
# 0    <class 'lightgbm.sklearn.LGBMClassifier'>          <class 'sklearn.linear_model._logistic.Logistic...  0.712500
#
#                                                                                                                   f1  \
# seed feat_sel                                           models
# 0    <class 'lightgbm.sklearn.LGBMClassifier'>          <class 'lightgbm.sklearn.LGBMClassifier'>           0.886003
# 2    <class 'sklearn.ensemble._forest.RandomForestCl... <class 'xgboost.sklearn.XGBClassifier'>             0.703030
# 1    <class 'sklearn.linear_model._logistic.Logistic... <class 'sklearn.ensemble._gb.GradientBoostingCl...  0.703030
#      <class 'sklearn.ensemble._forest.RandomForestCl... <class 'sklearn.ensemble._gb.GradientBoostingCl...  0.690909
# 2    <class 'lightgbm.sklearn.LGBMClassifier'>          <class 'sklearn.ensemble._bagging.BaggingClassi...  0.777778
# 1    <class 'lightgbm.sklearn.LGBMClassifier'>          <class 'sklearn.ensemble._forest.ExtraTreesClas...  0.800000
# 0    <class 'sklearn.linear_model._logistic.Logistic... <class 'sklearn.ensemble._gb.GradientBoostingCl...  0.759259
#      <class 'xgboost.sklearn.XGBClassifier'>            <class 'sklearn.svm._classes.SVC'>                  0.800000
#                                                         <class 'lightgbm.sklearn.LGBMClassifier'>           0.800000
#      <class 'sklearn.linear_model._logistic.Logistic... <class 'sklearn.linear_model._logistic.Logistic...  0.791667
#      <class 'lightgbm.sklearn.LGBMClassifier'>          <class 'sklearn.ensemble._weight_boosting.AdaBo...  0.791667
# 2    <class 'xgboost.sklearn.XGBClassifier'>            <class 'xgboost.sklearn.XGBClassifier'>             0.791667
# 1    <class 'sklearn.ensemble._forest.RandomForestCl... <class 'sklearn.ensemble._forest.RandomForestCl...  0.696970
#                                                         <class 'xgboost.sklearn.XGBClassifier'>             0.680619
# 2    <class 'lightgbm.sklearn.LGBMClassifier'>          <class 'sklearn.ensemble._forest.RandomForestCl...  0.719481
# 1    <class 'lightgbm.sklearn.LGBMClassifier'>          <class 'xgboost.sklearn.XGBClassifier'>             0.702564
# 2    <class 'lightgbm.sklearn.LGBMClassifier'>          <class 'sklearn.ensemble._gb.GradientBoostingCl...  0.702160
# 1    <class 'sklearn.ensemble._forest.RandomForestCl... <class 'sklearn.linear_model._logistic.Logistic...  0.727778
# 0    <class 'lightgbm.sklearn.LGBMClassifier'>          <class 'sklearn.linear_model._logistic.Logistic...  0.720779
#
#                                                                                                             accuracy_std  \
# seed feat_sel                                           models
# 0    <class 'lightgbm.sklearn.LGBMClassifier'>          <class 'lightgbm.sklearn.LGBMClassifier'>               0.000000
# 2    <class 'sklearn.ensemble._forest.RandomForestCl... <class 'xgboost.sklearn.XGBClassifier'>                 0.000000
# 1    <class 'sklearn.linear_model._logistic.Logistic... <class 'sklearn.ensemble._gb.GradientBoostingCl...      0.000000
#      <class 'sklearn.ensemble._forest.RandomForestCl... <class 'sklearn.ensemble._gb.GradientBoostingCl...      0.000000
# 2    <class 'lightgbm.sklearn.LGBMClassifier'>          <class 'sklearn.ensemble._bagging.BaggingClassi...      0.000000
# 1    <class 'lightgbm.sklearn.LGBMClassifier'>          <class 'sklearn.ensemble._forest.ExtraTreesClas...      0.000000
# 0    <class 'sklearn.linear_model._logistic.Logistic... <class 'sklearn.ensemble._gb.GradientBoostingCl...      0.000000
#      <class 'xgboost.sklearn.XGBClassifier'>            <class 'sklearn.svm._classes.SVC'>                      0.000000
#                                                         <class 'lightgbm.sklearn.LGBMClassifier'>               0.000000
#      <class 'sklearn.linear_model._logistic.Logistic... <class 'sklearn.linear_model._logistic.Logistic...      0.000000
#      <class 'lightgbm.sklearn.LGBMClassifier'>          <class 'sklearn.ensemble._weight_boosting.AdaBo...      0.000000
# 2    <class 'xgboost.sklearn.XGBClassifier'>            <class 'xgboost.sklearn.XGBClassifier'>                 0.000000
# 1    <class 'sklearn.ensemble._forest.RandomForestCl... <class 'sklearn.ensemble._forest.RandomForestCl...      0.000000
#                                                         <class 'xgboost.sklearn.XGBClassifier'>                 0.035355
# 2    <class 'lightgbm.sklearn.LGBMClassifier'>          <class 'sklearn.ensemble._forest.RandomForestCl...      0.070711
# 1    <class 'lightgbm.sklearn.LGBMClassifier'>          <class 'xgboost.sklearn.XGBClassifier'>                 0.117851
# 2    <class 'lightgbm.sklearn.LGBMClassifier'>          <class 'sklearn.ensemble._gb.GradientBoostingCl...      0.132288
# 1    <class 'sklearn.ensemble._forest.RandomForestCl... <class 'sklearn.linear_model._logistic.Logistic...      0.134715
# 0    <class 'lightgbm.sklearn.LGBMClassifier'>          <class 'sklearn.linear_model._logistic.Logistic...      0.229810
#
#                                                                                                               f1_std
# seed feat_sel                                           models
# 0    <class 'lightgbm.sklearn.LGBMClassifier'>          <class 'lightgbm.sklearn.LGBMClassifier'>           0.000000
# 2    <class 'sklearn.ensemble._forest.RandomForestCl... <class 'xgboost.sklearn.XGBClassifier'>             0.000000
# 1    <class 'sklearn.linear_model._logistic.Logistic... <class 'sklearn.ensemble._gb.GradientBoostingCl...  0.000000
#      <class 'sklearn.ensemble._forest.RandomForestCl... <class 'sklearn.ensemble._gb.GradientBoostingCl...  0.000000
# 2    <class 'lightgbm.sklearn.LGBMClassifier'>          <class 'sklearn.ensemble._bagging.BaggingClassi...  0.000000
# 1    <class 'lightgbm.sklearn.LGBMClassifier'>          <class 'sklearn.ensemble._forest.ExtraTreesClas...  0.000000
# 0    <class 'sklearn.linear_model._logistic.Logistic... <class 'sklearn.ensemble._gb.GradientBoostingCl...  0.000000
#      <class 'xgboost.sklearn.XGBClassifier'>            <class 'sklearn.svm._classes.SVC'>                  0.000000
#                                                         <class 'lightgbm.sklearn.LGBMClassifier'>           0.000000
#      <class 'sklearn.linear_model._logistic.Logistic... <class 'sklearn.linear_model._logistic.Logistic...  0.000000
#      <class 'lightgbm.sklearn.LGBMClassifier'>          <class 'sklearn.ensemble._weight_boosting.AdaBo...  0.000000
# 2    <class 'xgboost.sklearn.XGBClassifier'>            <class 'xgboost.sklearn.XGBClassifier'>             0.000000
# 1    <class 'sklearn.ensemble._forest.RandomForestCl... <class 'sklearn.ensemble._forest.RandomForestCl...  0.000000
#                                                         <class 'xgboost.sklearn.XGBClassifier'>             0.014552
# 2    <class 'lightgbm.sklearn.LGBMClassifier'>          <class 'sklearn.ensemble._forest.RandomForestCl...  0.086934
# 1    <class 'lightgbm.sklearn.LGBMClassifier'>          <class 'xgboost.sklearn.XGBClassifier'>             0.137795
# 2    <class 'lightgbm.sklearn.LGBMClassifier'>          <class 'sklearn.ensemble._gb.GradientBoostingCl...  0.127993
# 1    <class 'sklearn.ensemble._forest.RandomForestCl... <class 'sklearn.linear_model._logistic.Logistic...  0.125093
# 0    <class 'lightgbm.sklearn.LGBMClassifier'>          <class 'sklearn.linear_model._logistic.Logistic...  0.233662

# %%
mit_res_.head(10)
# Out:
#                                                                                                        accuracy  \
# feat_sel                                           models
# <class 'xgboost.sklearn.XGBClassifier'>            <class 'sklearn.svm._classes.SVC'>                  0.800000
# <class 'sklearn.linear_model._logistic.Logistic... <class 'sklearn.ensemble._gb.GradientBoostingCl...  0.729167
# <class 'lightgbm.sklearn.LGBMClassifier'>          <class 'sklearn.linear_model._logistic.Logistic...  0.712500
# <class 'xgboost.sklearn.XGBClassifier'>            <class 'xgboost.sklearn.XGBClassifier'>             0.712500
# <class 'lightgbm.sklearn.LGBMClassifier'>          <class 'lightgbm.sklearn.LGBMClassifier'>           0.700000
# <class 'sklearn.linear_model._logistic.Logistic... <class 'sklearn.linear_model._logistic.Logistic...  0.700000
# <class 'sklearn.ensemble._forest.RandomForestCl... <class 'xgboost.sklearn.XGBClassifier'>             0.681667
#                                                    <class 'sklearn.linear_model._logistic.Logistic...  0.666667
# <class 'lightgbm.sklearn.LGBMClassifier'>          <class 'sklearn.ensemble._forest.ExtraTreesClas...  0.663889
# <class 'xgboost.sklearn.XGBClassifier'>            <class 'sklearn.linear_model._logistic.Logistic...  0.658333
#
#                                                                                                              f1  \
# feat_sel                                           models
# <class 'xgboost.sklearn.XGBClassifier'>            <class 'sklearn.svm._classes.SVC'>                  0.800000
# <class 'sklearn.linear_model._logistic.Logistic... <class 'sklearn.ensemble._gb.GradientBoostingCl...  0.731145
# <class 'lightgbm.sklearn.LGBMClassifier'>          <class 'sklearn.linear_model._logistic.Logistic...  0.720779
# <class 'xgboost.sklearn.XGBClassifier'>            <class 'xgboost.sklearn.XGBClassifier'>             0.698397
# <class 'lightgbm.sklearn.LGBMClassifier'>          <class 'lightgbm.sklearn.LGBMClassifier'>           0.702261
# <class 'sklearn.linear_model._logistic.Logistic... <class 'sklearn.linear_model._logistic.Logistic...  0.694437
# <class 'sklearn.ensemble._forest.RandomForestCl... <class 'xgboost.sklearn.XGBClassifier'>             0.663359
#                                                    <class 'sklearn.linear_model._logistic.Logistic...  0.658761
# <class 'lightgbm.sklearn.LGBMClassifier'>          <class 'sklearn.ensemble._forest.ExtraTreesClas...  0.658460
# <class 'xgboost.sklearn.XGBClassifier'>            <class 'sklearn.linear_model._logistic.Logistic...  0.674059
#
#                                                                                                        accuracy_std  \
# feat_sel                                           models
# <class 'xgboost.sklearn.XGBClassifier'>            <class 'sklearn.svm._classes.SVC'>                      0.250000
# <class 'sklearn.linear_model._logistic.Logistic... <class 'sklearn.ensemble._gb.GradientBoostingCl...      0.169635
# <class 'lightgbm.sklearn.LGBMClassifier'>          <class 'sklearn.linear_model._logistic.Logistic...      0.239629
# <class 'xgboost.sklearn.XGBClassifier'>            <class 'xgboost.sklearn.XGBClassifier'>                 0.000000
# <class 'lightgbm.sklearn.LGBMClassifier'>          <class 'lightgbm.sklearn.LGBMClassifier'>               0.255155
# <class 'sklearn.linear_model._logistic.Logistic... <class 'sklearn.linear_model._logistic.Logistic...      0.036084
# <class 'sklearn.ensemble._forest.RandomForestCl... <class 'xgboost.sklearn.XGBClassifier'>                 0.072169
#                                                    <class 'sklearn.linear_model._logistic.Logistic...      0.224624
# <class 'lightgbm.sklearn.LGBMClassifier'>          <class 'sklearn.ensemble._forest.ExtraTreesClas...      0.036084
# <class 'xgboost.sklearn.XGBClassifier'>            <class 'sklearn.linear_model._logistic.Logistic...      0.088388
#
#                                                                                                          f1_std
# feat_sel                                           models
# <class 'xgboost.sklearn.XGBClassifier'>            <class 'sklearn.svm._classes.SVC'>                  0.116937
# <class 'sklearn.linear_model._logistic.Logistic... <class 'sklearn.ensemble._gb.GradientBoostingCl...  0.063460
# <class 'lightgbm.sklearn.LGBMClassifier'>          <class 'sklearn.linear_model._logistic.Logistic...  0.145565
# <class 'xgboost.sklearn.XGBClassifier'>            <class 'xgboost.sklearn.XGBClassifier'>             0.072452
# <class 'lightgbm.sklearn.LGBMClassifier'>          <class 'lightgbm.sklearn.LGBMClassifier'>           0.080578
# <class 'sklearn.linear_model._logistic.Logistic... <class 'sklearn.linear_model._logistic.Logistic...  0.038490
# <class 'sklearn.ensemble._forest.RandomForestCl... <class 'xgboost.sklearn.XGBClassifier'>             0.118373
#                                                    <class 'sklearn.linear_model._logistic.Logistic...  0.104319
# <class 'lightgbm.sklearn.LGBMClassifier'>          <class 'sklearn.ensemble._forest.ExtraTreesClas...  0.077536
# <class 'xgboost.sklearn.XGBClassifier'>            <class 'sklearn.linear_model._logistic.Logistic...  0.000000

# %% [markdown]
# probable best models `xgb`, `lr`

# %% [markdown]
# `lr` with `gbr` is a good model

# %%
rap_res = pd.read_csv('outputs/cv_results_Rapamycin_response.csv')

# %%
sum(rap_res['accuracy'] == np.nan)
# Out:
# 0

# %%
rap_res_all, rap_res_ = group_results(rap_res)

# %%
rap_res_all
# Out:
#                                                                                                             accuracy  \
# seed feat_sel                                           models
# 0    <class 'sklearn.linear_model._logistic.Logistic... <class 'sklearn.neighbors._classification.KNeig...  0.900000
# 2    <class 'sklearn.ensemble._forest.RandomForestCl... <class 'sklearn.svm._classes.SVC'>                  0.900000
#      <class 'sklearn.linear_model._logistic.Logistic... <class 'sklearn.ensemble._bagging.BaggingClassi...  0.900000
# 0    <class 'sklearn.linear_model._logistic.Logistic... <class 'sklearn.linear_model._logistic.Logistic...  0.850000
#                                                         <class 'sklearn.ensemble._gb.GradientBoostingCl...  0.800000
# ...                                                                                                              ...
# 2    <class 'lightgbm.sklearn.LGBMClassifier'>          <class 'sklearn.ensemble._bagging.BaggingClassi...  0.400000
# 0    <class 'lightgbm.sklearn.LGBMClassifier'>          <class 'lightgbm.sklearn.LGBMClassifier'>           0.366667
# 2    <class 'xgboost.sklearn.XGBClassifier'>            <class 'sklearn.svm._classes.SVC'>                  0.325000
#      <class 'sklearn.ensemble._forest.RandomForestCl... <class 'xgboost.sklearn.XGBClassifier'>             0.300000
#      <class 'lightgbm.sklearn.LGBMClassifier'>          <class 'sklearn.linear_model._logistic.Logistic...  0.200000
#
#                                                                                                                   f1  \
# seed feat_sel                                           models
# 0    <class 'sklearn.linear_model._logistic.Logistic... <class 'sklearn.neighbors._classification.KNeig...  0.898990
# 2    <class 'sklearn.ensemble._forest.RandomForestCl... <class 'sklearn.svm._classes.SVC'>                  0.898990
#      <class 'sklearn.linear_model._logistic.Logistic... <class 'sklearn.ensemble._bagging.BaggingClassi...  0.888889
# 0    <class 'sklearn.linear_model._logistic.Logistic... <class 'sklearn.linear_model._logistic.Logistic...  0.840278
#                                                         <class 'sklearn.ensemble._gb.GradientBoostingCl...  0.791667
# ...                                                                                                              ...
# 2    <class 'lightgbm.sklearn.LGBMClassifier'>          <class 'sklearn.ensemble._bagging.BaggingClassi...  0.400000
# 0    <class 'lightgbm.sklearn.LGBMClassifier'>          <class 'lightgbm.sklearn.LGBMClassifier'>           0.334499
# 2    <class 'xgboost.sklearn.XGBClassifier'>            <class 'sklearn.svm._classes.SVC'>                  0.333333
#      <class 'sklearn.ensemble._forest.RandomForestCl... <class 'xgboost.sklearn.XGBClassifier'>             0.292929
#      <class 'lightgbm.sklearn.LGBMClassifier'>          <class 'sklearn.linear_model._logistic.Logistic...  0.202020
#
#                                                                                                             accuracy_std  \
# seed feat_sel                                           models
# 0    <class 'sklearn.linear_model._logistic.Logistic... <class 'sklearn.neighbors._classification.KNeig...      0.000000
# 2    <class 'sklearn.ensemble._forest.RandomForestCl... <class 'sklearn.svm._classes.SVC'>                      0.000000
#      <class 'sklearn.linear_model._logistic.Logistic... <class 'sklearn.ensemble._bagging.BaggingClassi...      0.000000
# 0    <class 'sklearn.linear_model._logistic.Logistic... <class 'sklearn.linear_model._logistic.Logistic...      0.070711
#                                                         <class 'sklearn.ensemble._gb.GradientBoostingCl...      0.000000
# ...                                                                                                                  ...
# 2    <class 'lightgbm.sklearn.LGBMClassifier'>          <class 'sklearn.ensemble._bagging.BaggingClassi...      0.000000
# 0    <class 'lightgbm.sklearn.LGBMClassifier'>          <class 'lightgbm.sklearn.LGBMClassifier'>               0.152753
# 2    <class 'xgboost.sklearn.XGBClassifier'>            <class 'sklearn.svm._classes.SVC'>                      0.000000
#      <class 'sklearn.ensemble._forest.RandomForestCl... <class 'xgboost.sklearn.XGBClassifier'>                 0.000000
#      <class 'lightgbm.sklearn.LGBMClassifier'>          <class 'sklearn.linear_model._logistic.Logistic...      0.000000
#
#                                                                                                               f1_std
# seed feat_sel                                           models
# 0    <class 'sklearn.linear_model._logistic.Logistic... <class 'sklearn.neighbors._classification.KNeig...  0.000000
# 2    <class 'sklearn.ensemble._forest.RandomForestCl... <class 'sklearn.svm._classes.SVC'>                  0.000000
#      <class 'sklearn.linear_model._logistic.Logistic... <class 'sklearn.ensemble._bagging.BaggingClassi...  0.000000
# 0    <class 'sklearn.linear_model._logistic.Logistic... <class 'sklearn.linear_model._logistic.Logistic...  0.068746
#                                                         <class 'sklearn.ensemble._gb.GradientBoostingCl...  0.000000
# ...                                                                                                              ...
# 2    <class 'lightgbm.sklearn.LGBMClassifier'>          <class 'sklearn.ensemble._bagging.BaggingClassi...  0.000000
# 0    <class 'lightgbm.sklearn.LGBMClassifier'>          <class 'lightgbm.sklearn.LGBMClassifier'>           0.164266
# 2    <class 'xgboost.sklearn.XGBClassifier'>            <class 'sklearn.svm._classes.SVC'>                  0.000000
#      <class 'sklearn.ensemble._forest.RandomForestCl... <class 'xgboost.sklearn.XGBClassifier'>             0.000000
#      <class 'lightgbm.sklearn.LGBMClassifier'>          <class 'sklearn.linear_model._logistic.Logistic...  0.000000
#
# [87 rows x 4 columns]

# %%
rap_res_all[rap_res_all['accuracy'] >= 0.70].sort_values('accuracy_std')
# Out:
#                                                                                                             accuracy  \
# seed feat_sel                                           models
# 0    <class 'sklearn.linear_model._logistic.Logistic... <class 'sklearn.neighbors._classification.KNeig...    0.9000
# 2    <class 'sklearn.ensemble._forest.RandomForestCl... <class 'sklearn.svm._classes.SVC'>                    0.9000
#      <class 'sklearn.linear_model._logistic.Logistic... <class 'sklearn.ensemble._bagging.BaggingClassi...    0.9000
# 0    <class 'sklearn.linear_model._logistic.Logistic... <class 'sklearn.ensemble._gb.GradientBoostingCl...    0.8000
# 1    <class 'sklearn.ensemble._forest.RandomForestCl... <class 'sklearn.linear_model._logistic.Logistic...    0.8000
#      <class 'xgboost.sklearn.XGBClassifier'>            <class 'sklearn.ensemble._weight_boosting.AdaBo...    0.8000
# 0    <class 'sklearn.ensemble._forest.RandomForestCl... <class 'sklearn.ensemble._weight_boosting.AdaBo...    0.7000
# 1    <class 'lightgbm.sklearn.LGBMClassifier'>          <class 'lightgbm.sklearn.LGBMClassifier'>             0.7000
#                                                         <class 'sklearn.ensemble._weight_boosting.AdaBo...    0.7000
#      <class 'sklearn.ensemble._forest.RandomForestCl... <class 'sklearn.neighbors._classification.KNeig...    0.7000
# 2    <class 'sklearn.ensemble._forest.RandomForestCl... <class 'sklearn.ensemble._bagging.BaggingClassi...    0.7000
#      <class 'sklearn.linear_model._logistic.Logistic... <class 'sklearn.svm._classes.SVC'>                    0.7000
# 0    <class 'sklearn.ensemble._forest.RandomForestCl... <class 'sklearn.svm._classes.SVC'>                    0.7375
#      <class 'sklearn.linear_model._logistic.Logistic... <class 'sklearn.linear_model._logistic.Logistic...    0.8500
# 1    <class 'sklearn.linear_model._logistic.Logistic... <class 'sklearn.svm._classes.SVC'>                    0.7375
#
#                                                                                                                   f1  \
# seed feat_sel                                           models
# 0    <class 'sklearn.linear_model._logistic.Logistic... <class 'sklearn.neighbors._classification.KNeig...  0.898990
# 2    <class 'sklearn.ensemble._forest.RandomForestCl... <class 'sklearn.svm._classes.SVC'>                  0.898990
#      <class 'sklearn.linear_model._logistic.Logistic... <class 'sklearn.ensemble._bagging.BaggingClassi...  0.888889
# 0    <class 'sklearn.linear_model._logistic.Logistic... <class 'sklearn.ensemble._gb.GradientBoostingCl...  0.791667
# 1    <class 'sklearn.ensemble._forest.RandomForestCl... <class 'sklearn.linear_model._logistic.Logistic...  0.791667
#      <class 'xgboost.sklearn.XGBClassifier'>            <class 'sklearn.ensemble._weight_boosting.AdaBo...  0.791667
# 0    <class 'sklearn.ensemble._forest.RandomForestCl... <class 'sklearn.ensemble._weight_boosting.AdaBo...  0.670330
# 1    <class 'lightgbm.sklearn.LGBMClassifier'>          <class 'lightgbm.sklearn.LGBMClassifier'>           0.670330
#                                                         <class 'sklearn.ensemble._weight_boosting.AdaBo...  0.696970
#      <class 'sklearn.ensemble._forest.RandomForestCl... <class 'sklearn.neighbors._classification.KNeig...  0.696970
# 2    <class 'sklearn.ensemble._forest.RandomForestCl... <class 'sklearn.ensemble._bagging.BaggingClassi...  0.696970
#      <class 'sklearn.linear_model._logistic.Logistic... <class 'sklearn.svm._classes.SVC'>                  0.696970
# 0    <class 'sklearn.ensemble._forest.RandomForestCl... <class 'sklearn.svm._classes.SVC'>                  0.724054
#      <class 'sklearn.linear_model._logistic.Logistic... <class 'sklearn.linear_model._logistic.Logistic...  0.840278
# 1    <class 'sklearn.linear_model._logistic.Logistic... <class 'sklearn.svm._classes.SVC'>                  0.733333
#
#                                                                                                             accuracy_std  \
# seed feat_sel                                           models
# 0    <class 'sklearn.linear_model._logistic.Logistic... <class 'sklearn.neighbors._classification.KNeig...      0.000000
# 2    <class 'sklearn.ensemble._forest.RandomForestCl... <class 'sklearn.svm._classes.SVC'>                      0.000000
#      <class 'sklearn.linear_model._logistic.Logistic... <class 'sklearn.ensemble._bagging.BaggingClassi...      0.000000
# 0    <class 'sklearn.linear_model._logistic.Logistic... <class 'sklearn.ensemble._gb.GradientBoostingCl...      0.000000
# 1    <class 'sklearn.ensemble._forest.RandomForestCl... <class 'sklearn.linear_model._logistic.Logistic...      0.000000
#      <class 'xgboost.sklearn.XGBClassifier'>            <class 'sklearn.ensemble._weight_boosting.AdaBo...      0.000000
# 0    <class 'sklearn.ensemble._forest.RandomForestCl... <class 'sklearn.ensemble._weight_boosting.AdaBo...      0.000000
# 1    <class 'lightgbm.sklearn.LGBMClassifier'>          <class 'lightgbm.sklearn.LGBMClassifier'>               0.000000
#                                                         <class 'sklearn.ensemble._weight_boosting.AdaBo...      0.000000
#      <class 'sklearn.ensemble._forest.RandomForestCl... <class 'sklearn.neighbors._classification.KNeig...      0.000000
# 2    <class 'sklearn.ensemble._forest.RandomForestCl... <class 'sklearn.ensemble._bagging.BaggingClassi...      0.000000
#      <class 'sklearn.linear_model._logistic.Logistic... <class 'sklearn.svm._classes.SVC'>                      0.000000
# 0    <class 'sklearn.ensemble._forest.RandomForestCl... <class 'sklearn.svm._classes.SVC'>                      0.053033
#      <class 'sklearn.linear_model._logistic.Logistic... <class 'sklearn.linear_model._logistic.Logistic...      0.070711
# 1    <class 'sklearn.linear_model._logistic.Logistic... <class 'sklearn.svm._classes.SVC'>                      0.088388
#
#                                                                                                               f1_std
# seed feat_sel                                           models
# 0    <class 'sklearn.linear_model._logistic.Logistic... <class 'sklearn.neighbors._classification.KNeig...  0.000000
# 2    <class 'sklearn.ensemble._forest.RandomForestCl... <class 'sklearn.svm._classes.SVC'>                  0.000000
#      <class 'sklearn.linear_model._logistic.Logistic... <class 'sklearn.ensemble._bagging.BaggingClassi...  0.000000
# 0    <class 'sklearn.linear_model._logistic.Logistic... <class 'sklearn.ensemble._gb.GradientBoostingCl...  0.000000
# 1    <class 'sklearn.ensemble._forest.RandomForestCl... <class 'sklearn.linear_model._logistic.Logistic...  0.000000
#      <class 'xgboost.sklearn.XGBClassifier'>            <class 'sklearn.ensemble._weight_boosting.AdaBo...  0.000000
# 0    <class 'sklearn.ensemble._forest.RandomForestCl... <class 'sklearn.ensemble._weight_boosting.AdaBo...  0.000000
# 1    <class 'lightgbm.sklearn.LGBMClassifier'>          <class 'lightgbm.sklearn.LGBMClassifier'>           0.000000
#                                                         <class 'sklearn.ensemble._weight_boosting.AdaBo...  0.000000
#      <class 'sklearn.ensemble._forest.RandomForestCl... <class 'sklearn.neighbors._classification.KNeig...  0.000000
# 2    <class 'sklearn.ensemble._forest.RandomForestCl... <class 'sklearn.ensemble._bagging.BaggingClassi...  0.000000
#      <class 'sklearn.linear_model._logistic.Logistic... <class 'sklearn.svm._classes.SVC'>                  0.000000
# 0    <class 'sklearn.ensemble._forest.RandomForestCl... <class 'sklearn.svm._classes.SVC'>                  0.075977
#      <class 'sklearn.linear_model._logistic.Logistic... <class 'sklearn.linear_model._logistic.Logistic...  0.068746
# 1    <class 'sklearn.linear_model._logistic.Logistic... <class 'sklearn.svm._classes.SVC'>                  0.094281

# %%
rap_res_.head(10)
# Out:
#                                                                                                        accuracy  \
# feat_sel                                           models
# <class 'sklearn.ensemble._forest.RandomForestCl... <class 'sklearn.linear_model._logistic.Logistic...  0.800000
# <class 'sklearn.linear_model._logistic.Logistic... <class 'sklearn.ensemble._bagging.BaggingClassi...  0.750000
#                                                    <class 'sklearn.linear_model._logistic.Logistic...  0.721429
# <class 'sklearn.ensemble._forest.RandomForestCl... <class 'sklearn.svm._classes.SVC'>                  0.705000
# <class 'sklearn.linear_model._logistic.Logistic... <class 'sklearn.ensemble._gb.GradientBoostingCl...  0.700000
#                                                    <class 'sklearn.neighbors._classification.KNeig...  0.685714
#                                                    <class 'sklearn.svm._classes.SVC'>                  0.658333
# <class 'sklearn.ensemble._forest.RandomForestCl... <class 'sklearn.ensemble._bagging.BaggingClassi...  0.658333
# <class 'xgboost.sklearn.XGBClassifier'>            <class 'sklearn.ensemble._weight_boosting.AdaBo...  0.655000
# <class 'sklearn.ensemble._forest.RandomForestCl... <class 'sklearn.ensemble._weight_boosting.AdaBo...  0.612500
#
#                                                                                                              f1  \
# feat_sel                                           models
# <class 'sklearn.ensemble._forest.RandomForestCl... <class 'sklearn.linear_model._logistic.Logistic...  0.791667
# <class 'sklearn.linear_model._logistic.Logistic... <class 'sklearn.ensemble._bagging.BaggingClassi...  0.736111
#                                                    <class 'sklearn.linear_model._logistic.Logistic...  0.709993
# <class 'sklearn.ensemble._forest.RandomForestCl... <class 'sklearn.svm._classes.SVC'>                  0.697702
# <class 'sklearn.linear_model._logistic.Logistic... <class 'sklearn.ensemble._gb.GradientBoostingCl...  0.695833
#                                                    <class 'sklearn.neighbors._classification.KNeig...  0.677369
#                                                    <class 'sklearn.svm._classes.SVC'>                  0.650379
# <class 'sklearn.ensemble._forest.RandomForestCl... <class 'sklearn.ensemble._bagging.BaggingClassi...  0.644873
# <class 'xgboost.sklearn.XGBClassifier'>            <class 'sklearn.ensemble._weight_boosting.AdaBo...  0.651263
# <class 'sklearn.ensemble._forest.RandomForestCl... <class 'sklearn.ensemble._weight_boosting.AdaBo...  0.594098
#
#                                                                                                        accuracy_std  \
# feat_sel                                           models
# <class 'sklearn.ensemble._forest.RandomForestCl... <class 'sklearn.linear_model._logistic.Logistic...      0.224624
# <class 'sklearn.linear_model._logistic.Logistic... <class 'sklearn.ensemble._bagging.BaggingClassi...      0.000000
#                                                    <class 'sklearn.linear_model._logistic.Logistic...      0.036084
# <class 'sklearn.ensemble._forest.RandomForestCl... <class 'sklearn.svm._classes.SVC'>                      0.036084
# <class 'sklearn.linear_model._logistic.Logistic... <class 'sklearn.ensemble._gb.GradientBoostingCl...      0.169635
#                                                    <class 'sklearn.neighbors._classification.KNeig...      0.000000
#                                                    <class 'sklearn.svm._classes.SVC'>                      0.252591
# <class 'sklearn.ensemble._forest.RandomForestCl... <class 'sklearn.ensemble._bagging.BaggingClassi...      0.000000
# <class 'xgboost.sklearn.XGBClassifier'>            <class 'sklearn.ensemble._weight_boosting.AdaBo...      0.044194
# <class 'sklearn.ensemble._forest.RandomForestCl... <class 'sklearn.ensemble._weight_boosting.AdaBo...      0.062500
#
#                                                                                                          f1_std
# feat_sel                                           models
# <class 'sklearn.ensemble._forest.RandomForestCl... <class 'sklearn.linear_model._logistic.Logistic...  0.104319
# <class 'sklearn.linear_model._logistic.Logistic... <class 'sklearn.ensemble._bagging.BaggingClassi...  0.088735
#                                                    <class 'sklearn.linear_model._logistic.Logistic...  0.038490
# <class 'sklearn.ensemble._forest.RandomForestCl... <class 'sklearn.svm._classes.SVC'>                  0.062786
# <class 'sklearn.linear_model._logistic.Logistic... <class 'sklearn.ensemble._gb.GradientBoostingCl...  0.063460
#                                                    <class 'sklearn.neighbors._classification.KNeig...  0.000000
#                                                    <class 'sklearn.svm._classes.SVC'>                  0.097760
# <class 'sklearn.ensemble._forest.RandomForestCl... <class 'sklearn.ensemble._bagging.BaggingClassi...  0.072452
# <class 'xgboost.sklearn.XGBClassifier'>            <class 'sklearn.ensemble._weight_boosting.AdaBo...  0.041595
# <class 'sklearn.ensemble._forest.RandomForestCl... <class 'sklearn.ensemble._weight_boosting.AdaBo...  0.096681

# %%
mitful_res = pd.read_csv('outputs/cv_results_Mitomycin-Fulvestrant_response.csv')

# %%
sum(mitful_res['accuracy'] == np.nan)
# Out:
# 0

# %%
mitful_res_all, mitful_res_ = group_results(mitful_res)

# %%
mitful_res_all
# Out:
#                                                                                                             accuracy  \
# seed feat_sel                                           models
# 0    <class 'sklearn.ensemble._forest.RandomForestCl... <class 'sklearn.linear_model._logistic.Logistic...  0.875000
#      <class 'xgboost.sklearn.XGBClassifier'>            <class 'lightgbm.sklearn.LGBMClassifier'>           0.875000
# 2    <class 'sklearn.ensemble._forest.RandomForestCl... <class 'lightgbm.sklearn.LGBMClassifier'>           0.875000
# 0    <class 'sklearn.ensemble._forest.RandomForestCl... <class 'xgboost.sklearn.XGBClassifier'>             0.750000
#      <class 'sklearn.linear_model._logistic.Logistic... <class 'sklearn.ensemble._gb.GradientBoostingCl...  0.750000
# ...                                                                                                              ...
# 2    <class 'sklearn.ensemble._forest.RandomForestCl... <class 'sklearn.neighbors._classification.KNeig...  0.300000
#      <class 'sklearn.linear_model._logistic.Logistic... <class 'sklearn.ensemble._bagging.BaggingClassi...  0.300000
#      <class 'sklearn.ensemble._forest.RandomForestCl... <class 'sklearn.svm._classes.SVC'>                  0.200000
#      <class 'xgboost.sklearn.XGBClassifier'>            <class 'sklearn.linear_model._logistic.Logistic...  0.200000
#      <class 'sklearn.linear_model._logistic.Logistic... <class 'sklearn.neighbors._classification.KNeig...  0.166667
#
#                                                                                                                   f1  \
# seed feat_sel                                           models
# 0    <class 'sklearn.ensemble._forest.RandomForestCl... <class 'sklearn.linear_model._logistic.Logistic...  0.886003
#      <class 'xgboost.sklearn.XGBClassifier'>            <class 'lightgbm.sklearn.LGBMClassifier'>           0.896703
# 2    <class 'sklearn.ensemble._forest.RandomForestCl... <class 'lightgbm.sklearn.LGBMClassifier'>           0.896703
# 0    <class 'sklearn.ensemble._forest.RandomForestCl... <class 'xgboost.sklearn.XGBClassifier'>             0.759259
#      <class 'sklearn.linear_model._logistic.Logistic... <class 'sklearn.ensemble._gb.GradientBoostingCl...  0.759259
# ...                                                                                                              ...
# 2    <class 'sklearn.ensemble._forest.RandomForestCl... <class 'sklearn.neighbors._classification.KNeig...  0.277778
#      <class 'sklearn.linear_model._logistic.Logistic... <class 'sklearn.ensemble._bagging.BaggingClassi...  0.277778
#      <class 'sklearn.ensemble._forest.RandomForestCl... <class 'sklearn.svm._classes.SVC'>                  0.202020
#      <class 'xgboost.sklearn.XGBClassifier'>            <class 'sklearn.linear_model._logistic.Logistic...  0.166667
#      <class 'sklearn.linear_model._logistic.Logistic... <class 'sklearn.neighbors._classification.KNeig...  0.200000
#
#                                                                                                             accuracy_std  \
# seed feat_sel                                           models
# 0    <class 'sklearn.ensemble._forest.RandomForestCl... <class 'sklearn.linear_model._logistic.Logistic...           0.0
#      <class 'xgboost.sklearn.XGBClassifier'>            <class 'lightgbm.sklearn.LGBMClassifier'>                    0.0
# 2    <class 'sklearn.ensemble._forest.RandomForestCl... <class 'lightgbm.sklearn.LGBMClassifier'>                    0.0
# 0    <class 'sklearn.ensemble._forest.RandomForestCl... <class 'xgboost.sklearn.XGBClassifier'>                      0.0
#      <class 'sklearn.linear_model._logistic.Logistic... <class 'sklearn.ensemble._gb.GradientBoostingCl...           0.0
# ...                                                                                                                  ...
# 2    <class 'sklearn.ensemble._forest.RandomForestCl... <class 'sklearn.neighbors._classification.KNeig...           0.0
#      <class 'sklearn.linear_model._logistic.Logistic... <class 'sklearn.ensemble._bagging.BaggingClassi...           0.0
#      <class 'sklearn.ensemble._forest.RandomForestCl... <class 'sklearn.svm._classes.SVC'>                           0.0
#      <class 'xgboost.sklearn.XGBClassifier'>            <class 'sklearn.linear_model._logistic.Logistic...           0.0
#      <class 'sklearn.linear_model._logistic.Logistic... <class 'sklearn.neighbors._classification.KNeig...           0.0
#
#                                                                                                             f1_std
# seed feat_sel                                           models
# 0    <class 'sklearn.ensemble._forest.RandomForestCl... <class 'sklearn.linear_model._logistic.Logistic...     0.0
#      <class 'xgboost.sklearn.XGBClassifier'>            <class 'lightgbm.sklearn.LGBMClassifier'>              0.0
# 2    <class 'sklearn.ensemble._forest.RandomForestCl... <class 'lightgbm.sklearn.LGBMClassifier'>              0.0
# 0    <class 'sklearn.ensemble._forest.RandomForestCl... <class 'xgboost.sklearn.XGBClassifier'>                0.0
#      <class 'sklearn.linear_model._logistic.Logistic... <class 'sklearn.ensemble._gb.GradientBoostingCl...     0.0
# ...                                                                                                            ...
# 2    <class 'sklearn.ensemble._forest.RandomForestCl... <class 'sklearn.neighbors._classification.KNeig...     0.0
#      <class 'sklearn.linear_model._logistic.Logistic... <class 'sklearn.ensemble._bagging.BaggingClassi...     0.0
#      <class 'sklearn.ensemble._forest.RandomForestCl... <class 'sklearn.svm._classes.SVC'>                     0.0
#      <class 'xgboost.sklearn.XGBClassifier'>            <class 'sklearn.linear_model._logistic.Logistic...     0.0
#      <class 'sklearn.linear_model._logistic.Logistic... <class 'sklearn.neighbors._classification.KNeig...     0.0
#
# [91 rows x 4 columns]

# %%
mitful_res_all[mitful_res_all['accuracy'] >= 0.70].sort_values('accuracy_std')
# Out:
#                                                                                                             accuracy  \
# seed feat_sel                                           models
# 0    <class 'sklearn.ensemble._forest.RandomForestCl... <class 'sklearn.linear_model._logistic.Logistic...  0.875000
#      <class 'xgboost.sklearn.XGBClassifier'>            <class 'lightgbm.sklearn.LGBMClassifier'>           0.875000
# 2    <class 'sklearn.ensemble._forest.RandomForestCl... <class 'lightgbm.sklearn.LGBMClassifier'>           0.875000
# 0    <class 'sklearn.ensemble._forest.RandomForestCl... <class 'xgboost.sklearn.XGBClassifier'>             0.750000
#      <class 'sklearn.linear_model._logistic.Logistic... <class 'sklearn.ensemble._gb.GradientBoostingCl...  0.750000
# 2    <class 'lightgbm.sklearn.LGBMClassifier'>          <class 'sklearn.svm._classes.SVC'>                  0.750000
# 0    <class 'lightgbm.sklearn.LGBMClassifier'>          <class 'sklearn.linear_model._logistic.Logistic...  0.700000
# 1    <class 'sklearn.ensemble._forest.RandomForestCl... <class 'sklearn.ensemble._bagging.BaggingClassi...  0.700000
#                                                         <class 'sklearn.ensemble._forest.RandomForestCl...  0.700000
# 0    <class 'lightgbm.sklearn.LGBMClassifier'>          <class 'sklearn.ensemble._forest.ExtraTreesClas...  0.708333
#
#                                                                                                                   f1  \
# seed feat_sel                                           models
# 0    <class 'sklearn.ensemble._forest.RandomForestCl... <class 'sklearn.linear_model._logistic.Logistic...  0.886003
#      <class 'xgboost.sklearn.XGBClassifier'>            <class 'lightgbm.sklearn.LGBMClassifier'>           0.896703
# 2    <class 'sklearn.ensemble._forest.RandomForestCl... <class 'lightgbm.sklearn.LGBMClassifier'>           0.896703
# 0    <class 'sklearn.ensemble._forest.RandomForestCl... <class 'xgboost.sklearn.XGBClassifier'>             0.759259
#      <class 'sklearn.linear_model._logistic.Logistic... <class 'sklearn.ensemble._gb.GradientBoostingCl...  0.759259
# 2    <class 'lightgbm.sklearn.LGBMClassifier'>          <class 'sklearn.svm._classes.SVC'>                  0.780952
# 0    <class 'lightgbm.sklearn.LGBMClassifier'>          <class 'sklearn.linear_model._logistic.Logistic...  0.670330
# 1    <class 'sklearn.ensemble._forest.RandomForestCl... <class 'sklearn.ensemble._bagging.BaggingClassi...  0.696970
#                                                         <class 'sklearn.ensemble._forest.RandomForestCl...  0.696970
# 0    <class 'lightgbm.sklearn.LGBMClassifier'>          <class 'sklearn.ensemble._forest.ExtraTreesClas...  0.723954
#
#                                                                                                             accuracy_std  \
# seed feat_sel                                           models
# 0    <class 'sklearn.ensemble._forest.RandomForestCl... <class 'sklearn.linear_model._logistic.Logistic...      0.000000
#      <class 'xgboost.sklearn.XGBClassifier'>            <class 'lightgbm.sklearn.LGBMClassifier'>               0.000000
# 2    <class 'sklearn.ensemble._forest.RandomForestCl... <class 'lightgbm.sklearn.LGBMClassifier'>               0.000000
# 0    <class 'sklearn.ensemble._forest.RandomForestCl... <class 'xgboost.sklearn.XGBClassifier'>                 0.000000
#      <class 'sklearn.linear_model._logistic.Logistic... <class 'sklearn.ensemble._gb.GradientBoostingCl...      0.000000
# 2    <class 'lightgbm.sklearn.LGBMClassifier'>          <class 'sklearn.svm._classes.SVC'>                      0.000000
# 0    <class 'lightgbm.sklearn.LGBMClassifier'>          <class 'sklearn.linear_model._logistic.Logistic...      0.000000
# 1    <class 'sklearn.ensemble._forest.RandomForestCl... <class 'sklearn.ensemble._bagging.BaggingClassi...      0.000000
#                                                         <class 'sklearn.ensemble._forest.RandomForestCl...      0.000000
# 0    <class 'lightgbm.sklearn.LGBMClassifier'>          <class 'sklearn.ensemble._forest.ExtraTreesClas...      0.235702
#
#                                                                                                               f1_std
# seed feat_sel                                           models
# 0    <class 'sklearn.ensemble._forest.RandomForestCl... <class 'sklearn.linear_model._logistic.Logistic...  0.000000
#      <class 'xgboost.sklearn.XGBClassifier'>            <class 'lightgbm.sklearn.LGBMClassifier'>           0.000000
# 2    <class 'sklearn.ensemble._forest.RandomForestCl... <class 'lightgbm.sklearn.LGBMClassifier'>           0.000000
# 0    <class 'sklearn.ensemble._forest.RandomForestCl... <class 'xgboost.sklearn.XGBClassifier'>             0.000000
#      <class 'sklearn.linear_model._logistic.Logistic... <class 'sklearn.ensemble._gb.GradientBoostingCl...  0.000000
# 2    <class 'lightgbm.sklearn.LGBMClassifier'>          <class 'sklearn.svm._classes.SVC'>                  0.000000
# 0    <class 'lightgbm.sklearn.LGBMClassifier'>          <class 'sklearn.linear_model._logistic.Logistic...  0.000000
# 1    <class 'sklearn.ensemble._forest.RandomForestCl... <class 'sklearn.ensemble._bagging.BaggingClassi...  0.000000
#                                                         <class 'sklearn.ensemble._forest.RandomForestCl...  0.000000
# 0    <class 'lightgbm.sklearn.LGBMClassifier'>          <class 'sklearn.ensemble._forest.ExtraTreesClas...  0.229172

# %%
mitful_res_.head(10)
# Out:
#                                                                                                        accuracy  \
# feat_sel                                           models
# <class 'sklearn.ensemble._forest.RandomForestCl... <class 'sklearn.linear_model._logistic.Logistic...  0.705556
# <class 'lightgbm.sklearn.LGBMClassifier'>          <class 'sklearn.linear_model._logistic.Logistic...  0.683333
#                                                    <class 'sklearn.neighbors._classification.KNeig...  0.627778
#                                                    <class 'sklearn.svm._classes.SVC'>                  0.625000
# <class 'sklearn.ensemble._forest.RandomForestCl... <class 'sklearn.ensemble._forest.RandomForestCl...  0.550000
# <class 'sklearn.linear_model._logistic.Logistic... <class 'sklearn.ensemble._gb.GradientBoostingCl...  0.543750
# <class 'lightgbm.sklearn.LGBMClassifier'>          <class 'sklearn.ensemble._bagging.BaggingClassi...  0.543750
# <class 'sklearn.linear_model._logistic.Logistic... <class 'sklearn.ensemble._forest.ExtraTreesClas...  0.541667
# <class 'xgboost.sklearn.XGBClassifier'>            <class 'sklearn.ensemble._forest.ExtraTreesClas...  0.540278
# <class 'lightgbm.sklearn.LGBMClassifier'>          <class 'lightgbm.sklearn.LGBMClassifier'>           0.536111
#
#                                                                                                              f1  \
# feat_sel                                           models
# <class 'sklearn.ensemble._forest.RandomForestCl... <class 'sklearn.linear_model._logistic.Logistic...  0.714959
# <class 'lightgbm.sklearn.LGBMClassifier'>          <class 'sklearn.linear_model._logistic.Logistic...  0.680220
#                                                    <class 'sklearn.neighbors._classification.KNeig...  0.631913
#                                                    <class 'sklearn.svm._classes.SVC'>                  0.615476
# <class 'sklearn.ensemble._forest.RandomForestCl... <class 'sklearn.ensemble._forest.RandomForestCl...  0.438452
# <class 'sklearn.linear_model._logistic.Logistic... <class 'sklearn.ensemble._gb.GradientBoostingCl...  0.528830
# <class 'lightgbm.sklearn.LGBMClassifier'>          <class 'sklearn.ensemble._bagging.BaggingClassi...  0.549250
# <class 'sklearn.linear_model._logistic.Logistic... <class 'sklearn.ensemble._forest.ExtraTreesClas...  0.561905
# <class 'xgboost.sklearn.XGBClassifier'>            <class 'sklearn.ensemble._forest.ExtraTreesClas...  0.544076
# <class 'lightgbm.sklearn.LGBMClassifier'>          <class 'lightgbm.sklearn.LGBMClassifier'>           0.521757
#
#                                                                                                        accuracy_std  \
# feat_sel                                           models
# <class 'sklearn.ensemble._forest.RandomForestCl... <class 'sklearn.linear_model._logistic.Logistic...      0.224624
# <class 'lightgbm.sklearn.LGBMClassifier'>          <class 'sklearn.linear_model._logistic.Logistic...      0.239629
#                                                    <class 'sklearn.neighbors._classification.KNeig...      0.202293
#                                                    <class 'sklearn.svm._classes.SVC'>                      0.068465
# <class 'sklearn.ensemble._forest.RandomForestCl... <class 'sklearn.ensemble._forest.RandomForestCl...      0.000000
# <class 'sklearn.linear_model._logistic.Logistic... <class 'sklearn.ensemble._gb.GradientBoostingCl...      0.169635
# <class 'lightgbm.sklearn.LGBMClassifier'>          <class 'sklearn.ensemble._bagging.BaggingClassi...      0.000000
# <class 'sklearn.linear_model._logistic.Logistic... <class 'sklearn.ensemble._forest.ExtraTreesClas...      0.023623
# <class 'xgboost.sklearn.XGBClassifier'>            <class 'sklearn.ensemble._forest.ExtraTreesClas...      0.000000
# <class 'lightgbm.sklearn.LGBMClassifier'>          <class 'lightgbm.sklearn.LGBMClassifier'>               0.255155
#
#                                                                                                          f1_std
# feat_sel                                           models
# <class 'sklearn.ensemble._forest.RandomForestCl... <class 'sklearn.linear_model._logistic.Logistic...  0.104319
# <class 'lightgbm.sklearn.LGBMClassifier'>          <class 'sklearn.linear_model._logistic.Logistic...  0.145565
#                                                    <class 'sklearn.neighbors._classification.KNeig...  0.129767
#                                                    <class 'sklearn.svm._classes.SVC'>                  0.024680
# <class 'sklearn.ensemble._forest.RandomForestCl... <class 'sklearn.ensemble._forest.RandomForestCl...  0.000000
# <class 'sklearn.linear_model._logistic.Logistic... <class 'sklearn.ensemble._gb.GradientBoostingCl...  0.063460
# <class 'lightgbm.sklearn.LGBMClassifier'>          <class 'sklearn.ensemble._bagging.BaggingClassi...  0.064803
# <class 'sklearn.linear_model._logistic.Logistic... <class 'sklearn.ensemble._forest.ExtraTreesClas...  0.069029
# <class 'xgboost.sklearn.XGBClassifier'>            <class 'sklearn.ensemble._forest.ExtraTreesClas...  0.000000
# <class 'lightgbm.sklearn.LGBMClassifier'>          <class 'lightgbm.sklearn.LGBMClassifier'>           0.080578

# %% [markdown]
# probable best models `xgb`, `lr`

# %% [markdown]
# `lr` with `gbr` is a good model

# %%
rapgef_res = pd.read_csv('outputs/cv_results_Rapamycin-Gefitinib_response.csv')

# %%
sum(rapgef_res['accuracy'] == np.nan)
# Out:
# 0

# %%
rapgef_res_all, rapgef_res_ = group_results(rapgef_res)

# %%
rapgef_res_all
# Out:
#                                                                                                             accuracy  \
# seed feat_sel                                           models
# 1    <class 'lightgbm.sklearn.LGBMClassifier'>          <class 'sklearn.linear_model._logistic.Logistic...    0.8750
# 0    <class 'sklearn.linear_model._logistic.Logistic... <class 'sklearn.svm._classes.SVC'>                    0.8000
# 1    <class 'xgboost.sklearn.XGBClassifier'>            <class 'xgboost.sklearn.XGBClassifier'>               0.8000
# 0    <class 'sklearn.ensemble._forest.RandomForestCl... <class 'sklearn.neighbors._classification.KNeig...    0.7625
# 2    <class 'sklearn.linear_model._logistic.Logistic... <class 'sklearn.ensemble._weight_boosting.AdaBo...    0.7500
# ...                                                                                                              ...
# 1    <class 'sklearn.linear_model._logistic.Logistic... <class 'lightgbm.sklearn.LGBMClassifier'>             0.3000
# 2    <class 'lightgbm.sklearn.LGBMClassifier'>          <class 'xgboost.sklearn.XGBClassifier'>               0.3000
#      <class 'sklearn.ensemble._forest.RandomForestCl... <class 'sklearn.neighbors._classification.KNeig...    0.2000
#                                                         <class 'sklearn.svm._classes.SVC'>                    0.2000
#      <class 'sklearn.linear_model._logistic.Logistic... <class 'sklearn.linear_model._logistic.Logistic...    0.1000
#
#                                                                                                                   f1  \
# seed feat_sel                                           models
# 1    <class 'lightgbm.sklearn.LGBMClassifier'>          <class 'sklearn.linear_model._logistic.Logistic...  0.896703
# 0    <class 'sklearn.linear_model._logistic.Logistic... <class 'sklearn.svm._classes.SVC'>                  0.772222
# 1    <class 'xgboost.sklearn.XGBClassifier'>            <class 'xgboost.sklearn.XGBClassifier'>             0.791667
# 0    <class 'sklearn.ensemble._forest.RandomForestCl... <class 'sklearn.neighbors._classification.KNeig...  0.764444
# 2    <class 'sklearn.linear_model._logistic.Logistic... <class 'sklearn.ensemble._weight_boosting.AdaBo...  0.780952
# ...                                                                                                              ...
# 1    <class 'sklearn.linear_model._logistic.Logistic... <class 'lightgbm.sklearn.LGBMClassifier'>           0.277778
# 2    <class 'lightgbm.sklearn.LGBMClassifier'>          <class 'xgboost.sklearn.XGBClassifier'>             0.292929
#      <class 'sklearn.ensemble._forest.RandomForestCl... <class 'sklearn.neighbors._classification.KNeig...  0.200000
#                                                         <class 'sklearn.svm._classes.SVC'>                  0.200000
#      <class 'sklearn.linear_model._logistic.Logistic... <class 'sklearn.linear_model._logistic.Logistic...  0.090909
#
#                                                                                                             accuracy_std  \
# seed feat_sel                                           models
# 1    <class 'lightgbm.sklearn.LGBMClassifier'>          <class 'sklearn.linear_model._logistic.Logistic...      0.000000
# 0    <class 'sklearn.linear_model._logistic.Logistic... <class 'sklearn.svm._classes.SVC'>                      0.000000
# 1    <class 'xgboost.sklearn.XGBClassifier'>            <class 'xgboost.sklearn.XGBClassifier'>                 0.000000
# 0    <class 'sklearn.ensemble._forest.RandomForestCl... <class 'sklearn.neighbors._classification.KNeig...      0.194454
# 2    <class 'sklearn.linear_model._logistic.Logistic... <class 'sklearn.ensemble._weight_boosting.AdaBo...      0.000000
# ...                                                                                                                  ...
# 1    <class 'sklearn.linear_model._logistic.Logistic... <class 'lightgbm.sklearn.LGBMClassifier'>               0.000000
# 2    <class 'lightgbm.sklearn.LGBMClassifier'>          <class 'xgboost.sklearn.XGBClassifier'>                 0.000000
#      <class 'sklearn.ensemble._forest.RandomForestCl... <class 'sklearn.neighbors._classification.KNeig...      0.000000
#                                                         <class 'sklearn.svm._classes.SVC'>                      0.000000
#      <class 'sklearn.linear_model._logistic.Logistic... <class 'sklearn.linear_model._logistic.Logistic...      0.000000
#
#                                                                                                               f1_std
# seed feat_sel                                           models
# 1    <class 'lightgbm.sklearn.LGBMClassifier'>          <class 'sklearn.linear_model._logistic.Logistic...  0.000000
# 0    <class 'sklearn.linear_model._logistic.Logistic... <class 'sklearn.svm._classes.SVC'>                  0.000000
# 1    <class 'xgboost.sklearn.XGBClassifier'>            <class 'xgboost.sklearn.XGBClassifier'>             0.000000
# 0    <class 'sklearn.ensemble._forest.RandomForestCl... <class 'sklearn.neighbors._classification.KNeig...  0.175991
# 2    <class 'sklearn.linear_model._logistic.Logistic... <class 'sklearn.ensemble._weight_boosting.AdaBo...  0.000000
# ...                                                                                                              ...
# 1    <class 'sklearn.linear_model._logistic.Logistic... <class 'lightgbm.sklearn.LGBMClassifier'>           0.000000
# 2    <class 'lightgbm.sklearn.LGBMClassifier'>          <class 'xgboost.sklearn.XGBClassifier'>             0.000000
#      <class 'sklearn.ensemble._forest.RandomForestCl... <class 'sklearn.neighbors._classification.KNeig...  0.000000
#                                                         <class 'sklearn.svm._classes.SVC'>                  0.000000
#      <class 'sklearn.linear_model._logistic.Logistic... <class 'sklearn.linear_model._logistic.Logistic...  0.000000
#
# [91 rows x 4 columns]

# %%
rapgef_res_all[rapgef_res_all['accuracy'] >= 0.75].sort_values('accuracy_std')
# Out:
#                                                                                                             accuracy  \
# seed feat_sel                                           models
# 1    <class 'lightgbm.sklearn.LGBMClassifier'>          <class 'sklearn.linear_model._logistic.Logistic...    0.8750
# 0    <class 'sklearn.linear_model._logistic.Logistic... <class 'sklearn.svm._classes.SVC'>                    0.8000
# 1    <class 'xgboost.sklearn.XGBClassifier'>            <class 'xgboost.sklearn.XGBClassifier'>               0.8000
# 2    <class 'sklearn.linear_model._logistic.Logistic... <class 'sklearn.ensemble._weight_boosting.AdaBo...    0.7500
# 0    <class 'sklearn.ensemble._forest.RandomForestCl... <class 'sklearn.neighbors._classification.KNeig...    0.7625
#
#                                                                                                                   f1  \
# seed feat_sel                                           models
# 1    <class 'lightgbm.sklearn.LGBMClassifier'>          <class 'sklearn.linear_model._logistic.Logistic...  0.896703
# 0    <class 'sklearn.linear_model._logistic.Logistic... <class 'sklearn.svm._classes.SVC'>                  0.772222
# 1    <class 'xgboost.sklearn.XGBClassifier'>            <class 'xgboost.sklearn.XGBClassifier'>             0.791667
# 2    <class 'sklearn.linear_model._logistic.Logistic... <class 'sklearn.ensemble._weight_boosting.AdaBo...  0.780952
# 0    <class 'sklearn.ensemble._forest.RandomForestCl... <class 'sklearn.neighbors._classification.KNeig...  0.764444
#
#                                                                                                             accuracy_std  \
# seed feat_sel                                           models
# 1    <class 'lightgbm.sklearn.LGBMClassifier'>          <class 'sklearn.linear_model._logistic.Logistic...      0.000000
# 0    <class 'sklearn.linear_model._logistic.Logistic... <class 'sklearn.svm._classes.SVC'>                      0.000000
# 1    <class 'xgboost.sklearn.XGBClassifier'>            <class 'xgboost.sklearn.XGBClassifier'>                 0.000000
# 2    <class 'sklearn.linear_model._logistic.Logistic... <class 'sklearn.ensemble._weight_boosting.AdaBo...      0.000000
# 0    <class 'sklearn.ensemble._forest.RandomForestCl... <class 'sklearn.neighbors._classification.KNeig...      0.194454
#
#                                                                                                               f1_std
# seed feat_sel                                           models
# 1    <class 'lightgbm.sklearn.LGBMClassifier'>          <class 'sklearn.linear_model._logistic.Logistic...  0.000000
# 0    <class 'sklearn.linear_model._logistic.Logistic... <class 'sklearn.svm._classes.SVC'>                  0.000000
# 1    <class 'xgboost.sklearn.XGBClassifier'>            <class 'xgboost.sklearn.XGBClassifier'>             0.000000
# 2    <class 'sklearn.linear_model._logistic.Logistic... <class 'sklearn.ensemble._weight_boosting.AdaBo...  0.000000
# 0    <class 'sklearn.ensemble._forest.RandomForestCl... <class 'sklearn.neighbors._classification.KNeig...  0.175991

# %%
rapgef_res_.head(10)
# Out:
#                                                                                                        accuracy  \
# feat_sel                                           models
# <class 'xgboost.sklearn.XGBClassifier'>            <class 'xgboost.sklearn.XGBClassifier'>             0.725000
# <class 'sklearn.linear_model._logistic.Logistic... <class 'sklearn.svm._classes.SVC'>                  0.650000
# <class 'sklearn.ensemble._forest.RandomForestCl... <class 'lightgbm.sklearn.LGBMClassifier'>           0.629167
# <class 'lightgbm.sklearn.LGBMClassifier'>          <class 'sklearn.ensemble._forest.ExtraTreesClas...  0.625000
# <class 'sklearn.ensemble._forest.RandomForestCl... <class 'sklearn.ensemble._gb.GradientBoostingCl...  0.581944
# <class 'xgboost.sklearn.XGBClassifier'>            <class 'sklearn.svm._classes.SVC'>                  0.575000
# <class 'lightgbm.sklearn.LGBMClassifier'>          <class 'sklearn.ensemble._gb.GradientBoostingCl...  0.550000
# <class 'xgboost.sklearn.XGBClassifier'>            <class 'sklearn.neighbors._classification.KNeig...  0.548611
# <class 'lightgbm.sklearn.LGBMClassifier'>          <class 'sklearn.linear_model._logistic.Logistic...  0.548333
# <class 'xgboost.sklearn.XGBClassifier'>            <class 'sklearn.linear_model._logistic.Logistic...  0.545000
#
#                                                                                                              f1  \
# feat_sel                                           models
# <class 'xgboost.sklearn.XGBClassifier'>            <class 'xgboost.sklearn.XGBClassifier'>             0.724838
# <class 'sklearn.linear_model._logistic.Logistic... <class 'sklearn.svm._classes.SVC'>                  0.584524
# <class 'sklearn.ensemble._forest.RandomForestCl... <class 'lightgbm.sklearn.LGBMClassifier'>           0.613725
# <class 'lightgbm.sklearn.LGBMClassifier'>          <class 'sklearn.ensemble._forest.ExtraTreesClas...  0.640000
# <class 'sklearn.ensemble._forest.RandomForestCl... <class 'sklearn.ensemble._gb.GradientBoostingCl...  0.585532
# <class 'xgboost.sklearn.XGBClassifier'>            <class 'sklearn.svm._classes.SVC'>                  0.547010
# <class 'lightgbm.sklearn.LGBMClassifier'>          <class 'sklearn.ensemble._gb.GradientBoostingCl...  0.502671
# <class 'xgboost.sklearn.XGBClassifier'>            <class 'sklearn.neighbors._classification.KNeig...  0.537038
# <class 'lightgbm.sklearn.LGBMClassifier'>          <class 'sklearn.linear_model._logistic.Logistic...  0.533677
# <class 'xgboost.sklearn.XGBClassifier'>            <class 'sklearn.linear_model._logistic.Logistic...  0.525685
#
#                                                                                                        accuracy_std  \
# feat_sel                                           models
# <class 'xgboost.sklearn.XGBClassifier'>            <class 'xgboost.sklearn.XGBClassifier'>                 0.000000
# <class 'sklearn.linear_model._logistic.Logistic... <class 'sklearn.svm._classes.SVC'>                      0.252591
# <class 'sklearn.ensemble._forest.RandomForestCl... <class 'lightgbm.sklearn.LGBMClassifier'>               0.138585
# <class 'lightgbm.sklearn.LGBMClassifier'>          <class 'sklearn.ensemble._forest.ExtraTreesClas...      0.036084
# <class 'sklearn.ensemble._forest.RandomForestCl... <class 'sklearn.ensemble._gb.GradientBoostingCl...      0.000000
# <class 'xgboost.sklearn.XGBClassifier'>            <class 'sklearn.svm._classes.SVC'>                      0.250000
# <class 'lightgbm.sklearn.LGBMClassifier'>          <class 'sklearn.ensemble._gb.GradientBoostingCl...      0.272431
# <class 'xgboost.sklearn.XGBClassifier'>            <class 'sklearn.neighbors._classification.KNeig...      0.036084
# <class 'lightgbm.sklearn.LGBMClassifier'>          <class 'sklearn.linear_model._logistic.Logistic...      0.239629
# <class 'xgboost.sklearn.XGBClassifier'>            <class 'sklearn.linear_model._logistic.Logistic...      0.088388
#
#                                                                                                          f1_std
# feat_sel                                           models
# <class 'xgboost.sklearn.XGBClassifier'>            <class 'xgboost.sklearn.XGBClassifier'>             0.072452
# <class 'sklearn.linear_model._logistic.Logistic... <class 'sklearn.svm._classes.SVC'>                  0.097760
# <class 'sklearn.ensemble._forest.RandomForestCl... <class 'lightgbm.sklearn.LGBMClassifier'>           0.106054
# <class 'lightgbm.sklearn.LGBMClassifier'>          <class 'sklearn.ensemble._forest.ExtraTreesClas...  0.077536
# <class 'sklearn.ensemble._forest.RandomForestCl... <class 'sklearn.ensemble._gb.GradientBoostingCl...  0.000000
# <class 'xgboost.sklearn.XGBClassifier'>            <class 'sklearn.svm._classes.SVC'>                  0.116937
# <class 'lightgbm.sklearn.LGBMClassifier'>          <class 'sklearn.ensemble._gb.GradientBoostingCl...  0.126198
# <class 'xgboost.sklearn.XGBClassifier'>            <class 'sklearn.neighbors._classification.KNeig...  0.051281
# <class 'lightgbm.sklearn.LGBMClassifier'>          <class 'sklearn.linear_model._logistic.Logistic...  0.145565
# <class 'xgboost.sklearn.XGBClassifier'>            <class 'sklearn.linear_model._logistic.Logistic...  0.000000

# %% [markdown]
# `lr` with `gbr` is a good model

# %%
from collections import Counter

def merge_dictionaries(dict1, dict2):
    counter1 = Counter(dict1)
    counter2 = Counter(dict2)

    merged_counter = counter1 + counter2
    merged_dict = dict(merged_counter)

    return merged_dict

# Example usage:
dict1 = {'a': 1, 'b': 2, 'c': 3}
dict2 = {'b': 5, 'c': 7, 'd': 9}

merged_dict = merge_dictionaries(dict1, dict2)
print(merged_dict)
# Out:
# {'a': 1, 'b': 7, 'c': 10, 'd': 9}

# %%
import pandas as pd

# Sample DataFrames (replace these with your actual DataFrames)
df1 = pd.DataFrame({
    'seed': [38, 4, 94, 64, 73],
    'feat_sel': [1, 0, 0, 0, 2],
    'models': ['LGBM', 'LGBM', 'KNeighbors', 'XGB', 'Logistic'],
    'accuracy': [1.0, 1.0, 1.0, 0.9375, 0.9375],
    'f1': [1.0, 1.0, 1.0, 0.903704, 0.903704]
})

df2 = pd.DataFrame({
    'seed': [0, 2, 0, 1, 2, 0, 1],
    'feat_sel': ['RandomForest', 'Logistic', 'LGBM', 'Logistic', 'XGB', 'LGBM', 'LGBM'],
    'models': ['Logistic', 'SVC', 'LGBM', 'GradientBoosting', 'GradientBoosting', 'Logistic', 'GradientBoosting'],
    'accuracy': [0.9375, 0.9375, 0.875, 0.75, 0.75, 0.78125, 0.75],
    'f1': [0.906667, 0.903704, 0.819048, 0.633333, 0.886275, 0.819048, 0.855556],
    'accuracy_std': [0, 0, 0, 0, 0, 0.309359, 0.353553],
    'f1_std': [0, 0, 0, 0, 0, 0.255905, 0.204275]
})

# Merge and filter
merged_df = pd.concat([df1, df2], on=['seed', 'feat_sel', 'models', 'model_params'], join='inner')

# Display the result
print(merged_df)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /Users/sparshgupta/Library/Mobile Documents/iCloud~md~obsidian/Documents/Sparsh Gupta/Projects/lantern pharma hackathon/inference.ipynb Cell 53 line 2
#      <a href='vscode-notebook-cell:/Users/sparshgupta/Library/Mobile%20Documents/iCloud~md~obsidian/Documents/Sparsh%20Gupta/Projects/lantern%20pharma%20hackathon/inference.ipynb#Y214sZmlsZQ%3D%3D?line=11'>12</a> df2 = pd.DataFrame({
#      <a href='vscode-notebook-cell:/Users/sparshgupta/Library/Mobile%20Documents/iCloud~md~obsidian/Documents/Sparsh%20Gupta/Projects/lantern%20pharma%20hackathon/inference.ipynb#Y214sZmlsZQ%3D%3D?line=12'>13</a>     'seed': [0, 2, 0, 1, 2, 0, 1],
#      <a href='vscode-notebook-cell:/Users/sparshgupta/Library/Mobile%20Documents/iCloud~md~obsidian/Documents/Sparsh%20Gupta/Projects/lantern%20pharma%20hackathon/inference.ipynb#Y214sZmlsZQ%3D%3D?line=13'>14</a>     'feat_sel': ['RandomForest', 'Logistic', 'LGBM', 'Logistic', 'XGB', 'LGBM', 'LGBM'],
#    (...)
#      <a href='vscode-notebook-cell:/Users/sparshgupta/Library/Mobile%20Documents/iCloud~md~obsidian/Documents/Sparsh%20Gupta/Projects/lantern%20pharma%20hackathon/inference.ipynb#Y214sZmlsZQ%3D%3D?line=18'>19</a>     'f1_std': [0, 0, 0, 0, 0, 0.255905, 0.204275]
#      <a href='vscode-notebook-cell:/Users/sparshgupta/Library/Mobile%20Documents/iCloud~md~obsidian/Documents/Sparsh%20Gupta/Projects/lantern%20pharma%20hackathon/inference.ipynb#Y214sZmlsZQ%3D%3D?line=19'>20</a> })
#      <a href='vscode-notebook-cell:/Users/sparshgupta/Library/Mobile%20Documents/iCloud~md~obsidian/Documents/Sparsh%20Gupta/Projects/lantern%20pharma%20hackathon/inference.ipynb#Y214sZmlsZQ%3D%3D?line=21'>22</a> # Merge and filter
# ---> <a href='vscode-notebook-cell:/Users/sparshgupta/Library/Mobile%20Documents/iCloud~md~obsidian/Documents/Sparsh%20Gupta/Projects/lantern%20pharma%20hackathon/inference.ipynb#Y214sZmlsZQ%3D%3D?line=22'>23</a> merged_df = pd.concat([df1, df2], on=['seed', 'feat_sel', 'models'], how='inner')
#      <a href='vscode-notebook-cell:/Users/sparshgupta/Library/Mobile%20Documents/iCloud~md~obsidian/Documents/Sparsh%20Gupta/Projects/lantern%20pharma%20hackathon/inference.ipynb#Y214sZmlsZQ%3D%3D?line=24'>25</a> # Display the result
#      <a href='vscode-notebook-cell:/Users/sparshgupta/Library/Mobile%20Documents/iCloud~md~obsidian/Documents/Sparsh%20Gupta/Projects/lantern%20pharma%20hackathon/inference.ipynb#Y214sZmlsZQ%3D%3D?line=25'>26</a> print(merged_df)
#
# File ~/mambaforge/envs/optim_env/lib/python3.11/site-packages/pandas/util/_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# TypeError: concat() got an unexpected keyword argument 'on'

# %%
df1
# Out:
#    ID     Name  Score
# 0   1    Alice     85
# 1   2      Bob     92
# 2   3  Charlie     78
# 3   4    David     95
# 4   5      Eve     88

# %%
df2
# Out:
#    ID   Name
# 0   2    Bob
# 1   4  David

# %%
pd.DataFrame.from_dict({"adefwc":23, "cdcdacdw":34, "adecwfwc":232, "cdcdacdwcw":354, "adewcfwc":623, "cdcdacdw":314}, index=0)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /Users/sparshgupta/Library/Mobile Documents/iCloud~md~obsidian/Documents/Sparsh Gupta/Projects/lantern pharma hackathon/inference.ipynb Cell 59 line 1
# ----> <a href='vscode-notebook-cell:/Users/sparshgupta/Library/Mobile%20Documents/iCloud~md~obsidian/Documents/Sparsh%20Gupta/Projects/lantern%20pharma%20hackathon/inference.ipynb#Y223sZmlsZQ%3D%3D?line=0'>1</a> pd.DataFrame.from_dict({"adefwc":23, "cdcdacdw":34, "adecwfwc":232, "cdcdacdwcw":354, "adewcfwc":623, "cdcdacdw":314}, index=0)
#
# TypeError: DataFrame.from_dict() got an unexpected keyword argument 'index'

# %%
def dict_to_dataframe(input_dict):
    df = pd.DataFrame(list(input_dict.items()), columns=['features', 'feature_importance'])
    return df

# %%
dict_to_dataframe({"adefwc":23, "cdcdacdw":34, "adecwfwc":232, "cdcdacdwcw":354, "adewcfwc":623, "cdcdacdw":314})
# Out:
#      features  feature_importance
# 0      adefwc                  23
# 1    cdcdacdw                 314
# 2    adecwfwc                 232
# 3  cdcdacdwcw                 354
# 4    adewcfwc                 623

# %%
from utils import prep_test
import pandas as pd

traindf = pd.read_csv("allTrain.tsv", sep="\t", low_memory=True)
testdf = pd.read_csv("testData.tsv", sep="\t", low_memory=True, index_col=0)
_, _, _, _, X_train, y_train = get_train_test_split(traindf)
X_test = prep_test(testdf)

# %%
X_test.shape
# Out:
# (9, 15989)

# %%
X_train.shape
# Out:
# (48, 15989)

# %%
np.all(X_train.columns == X_test.columns)
# Out:
# True

# %%
diff_cols = X_train.columns != X_test.columns
test_cols = X_test.iloc[:, diff_cols].columns.to_list()
train_cols = X_train.iloc[:, diff_cols].columns.tolist()
rename_cols = dict(zip(test_cols, train_cols))
X_test = X_test.rename(rename_cols, axis=1)

# %%
cols = X_test.iloc[:,(X_train.columns!=X_test.columns)].columns.to_list()
newcols = [f'{col.split(".")[0]}-{col.split(".")[1]}' for col in cols]

# %%
cols = X_test.iloc[:,(X_train.columns!=X_test.columns)].columns.to_list()
cols
# Out:
# ['rna_CTB-178M22',
#  'rna_CTC-338M12',
#  'rna_GS1-124K5',
#  'rna_DTX2P1-UPK3BP1',
#  'rna_GS1-259H13',
#  'rna_STAG3L5P-PVRIG2P',
#  'rna_CH17-360D5',
#  'rna_THRA1-BTR',
#  'rna_CH17-340M24']

# %%
rename_cols = dict(zip(cols,newcols))
X_test = X_test.rename(rename_cols, axis=1)

# %%
train_cols = X_train.iloc[:,(X_train.columns!=X_test.columns)].columns.tolist()

# %%
train_cols
# Out:
# ['rna_CTB-178M22.2',
#  'rna_CTC-338M12.4',
#  'rna_GS1-124K5.11',
#  'rna_DTX2P1-UPK3BP1-PMS2P11',
#  'rna_GS1-259H13.2',
#  'rna_STAG3L5P-PVRIG2P-PILRB',
#  'rna_CH17-360D5.1',
#  'rna_THRA1/BTR',
#  'rna_CH17-340M24.3']
